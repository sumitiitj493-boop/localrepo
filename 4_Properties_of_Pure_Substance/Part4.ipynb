# %% [markdown]
# <div style="background: linear-gradient(to right, #667eea, #764ba2); padding: 20px; border-left: 5px solid #ffeb3b; border-radius: 8px;">
# <h1 style="color: #ffffff; margin:0;">🔥 PART 4 - PRACTICE SESSION 🔥</h1>
# <p style="color: #ffffff; margin-top:5px; font-size: 18px;">Time to Apply Everything You've Learned! 💪</p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h2 style="color: #58a6ff; margin-top:0;">📋 How This Works</h2>
# <ol style="color: #c9d1d9; line-height: 1.8; font-size: 16px;">
# <li>Read the problem carefully 📖</li>
# <li>Try solving it on your own first ✍️</li>
# <li>Stuck? Click <strong style="color: #d29922;">"Hint"</strong> for a nudge in the right direction 💡</li>
# <li>Still struggling? Click <strong style="color: #3fb950;">"Full Solution"</strong> to see step-by-step solution 🎯</li>
# <li>Learn from the solution and try similar problems! 🚀</li>
# </ol>
# <p style="color: #f85149; font-weight: bold; margin-top: 15px; font-size: 16px;">
# ⚠️ No cheating! Try solving first before clicking hints! 😄
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #58a6ff; border-radius: 8px;">
# <h2 style="color: #58a6ff; margin:0;">📘 SECTION 1: Phase Diagrams & Quality</h2>
# <p style="color: #8b949e; margin-top:5px;">From Part 1 - Fundamentals</p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #58a6ff; margin-top: 20px;">
# <h3 style="color: #3fb950; margin-top:0;">🎯 Problem 1.1: Identifying States</h3>
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; margin-top: 10px;">
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# Water is at the following conditions. Identify whether it is <strong>subcooled liquid</strong>, <strong>saturated liquid</strong>, <strong>two-phase mixture</strong>, <strong>saturated vapor</strong>, or <strong>superheated vapor</strong>:
# </p>
# <ol style="color: #c9d1d9; line-height: 1.8;">
# <li>T = 120°C, p = 1 bar</li>
# <li>T = 100°C, p = 1.014 bar</li>
# <li>T = 100°C, quality x = 0.5, p = 1.014 bar</li>
# <li>T = 80°C, p = 5 bar</li>
# <li>T = 200°C, p = 1 bar</li>
# </ol>
# </div>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #d29922;">
# <summary style="color: #d29922; font-weight: bold; cursor: pointer; font-size: 16px;">💡 Click here for Hint</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p><strong>Hint:</strong></p>
# <ul>
# <li>At 1.014 bar (atmospheric pressure), saturation temperature = 100°C</li>
# <li>If T < T<sub>sat</sub> → Subcooled liquid</li>
# <li>If T = T<sub>sat</sub> and no quality given → Could be saturated (assume saturated liquid or check)</li>
# <li>If quality is given → Two-phase mixture</li>
# <li>If T > T<sub>sat</sub> → Superheated vapor</li>
# <li>At higher pressure, T<sub>sat</sub> is higher!</li>
# </ul>
# </div>
# </details>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #3fb950;">
# <summary style="color: #3fb950; font-weight: bold; cursor: pointer; font-size: 16px;">✅ Click here for Full Solution</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">Solution:</p>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Case 1: T = 120°C, p = 1 bar</p>
# <p>At p = 1 bar, T<sub>sat</sub> ≈ 99.6°C</p>
# <p>Since T (120°C) > T<sub>sat</sub> (99.6°C)</p>
# <p style="color: #3fb950; font-weight: bold;">Answer: SUPERHEATED VAPOR ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Case 2: T = 100°C, p = 1.014 bar</p>
# <p>At p = 1.014 bar, T<sub>sat</sub> = 100°C</p>
# <p>Since T = T<sub>sat</sub> and no quality given</p>
# <p style="color: #3fb950; font-weight: bold;">Answer: SATURATED LIQUID (state f) ✅</p>
# <p style="color: #8b949e; font-style: italic;">(Could also be saturated vapor, but convention is saturated liquid if not specified)</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Case 3: T = 100°C, x = 0.5, p = 1.014 bar</p>
# <p>Quality is given, and 0 < x < 1</p>
# <p style="color: #3fb950; font-weight: bold;">Answer: TWO-PHASE MIXTURE ✅</p>
# <p style="color: #8b949e; font-style: italic;">(50% liquid, 50% vapor by mass)</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Case 4: T = 80°C, p = 5 bar</p>
# <p>At p = 5 bar, T<sub>sat</sub> ≈ 151.8°C</p>
# <p>Since T (80°C) < T<sub>sat</sub> (151.8°C)</p>
# <p style="color: #3fb950; font-weight: bold;">Answer: SUBCOOLED LIQUID (Compressed Liquid) ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Case 5: T = 200°C, p = 1 bar</p>
# <p>At p = 1 bar, T<sub>sat</sub> ≈ 99.6°C</p>
# <p>Since T (200°C) >> T<sub>sat</sub> (99.6°C)</p>
# <p style="color: #3fb950; font-weight: bold;">Answer: SUPERHEATED VAPOR ✅</p>
# </div>
#
# <p style="color: #a371f7; margin-top: 15px; font-weight: bold;">🎯 Key Takeaway:</p>
# <p>Always compare T with T<sub>sat</sub> at the given pressure to identify the state!</p>
# </div>
# </details>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #58a6ff; margin-top: 20px;">
# <h3 style="color: #3fb950; margin-top:0;">🎯 Problem 1.2: Quality Calculation</h3>
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; margin-top: 10px;">
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# A rigid tank contains 5 kg of water at 100°C. The volume of the tank is 1.2 m³.
# </p>
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# <strong>Find:</strong> The quality of the mixture.
# </p>
# <p style="color: #8b949e; font-style: italic;">
# Given: At 100°C, v<sub>f</sub> = 0.001044 m³/kg, v<sub>g</sub> = 1.6729 m³/kg
# </p>
# </div>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #d29922;">
# <summary style="color: #d29922; font-weight: bold; cursor: pointer; font-size: 16px;">💡 Click here for Hint</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p><strong>Hints:</strong></p>
# <ol>
# <li>First calculate the specific volume: v = V/M</li>
# <li>Since it's at 100°C (saturation temperature), check if v is between v<sub>f</sub> and v<sub>g</sub></li>
# <li>If yes, it's a two-phase mixture!</li>
# <li>Use the quality formula: v = (1-x)·v<sub>f</sub> + x·v<sub>g</sub></li>
# <li>Solve for x!</li>
# </ol>
# </div>
# </details>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #3fb950;">
# <summary style="color: #3fb950; font-weight: bold; cursor: pointer; font-size: 16px;">✅ Click here for Full Solution</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">Solution:</p>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 1: Calculate specific volume</p>
# <p>v = V/M = 1.2 m³ / 5 kg = 0.24 m³/kg</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 2: Check the state</p>
# <p>v<sub>f</sub> = 0.001044 m³/kg < v = 0.24 m³/kg < v<sub>g</sub> = 1.6729 m³/kg</p>
# <p style="color: #3fb950;">Since v is between v<sub>f</sub> and v<sub>g</sub>, it's a TWO-PHASE MIXTURE! ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 3: Use quality formula</p>
# <p>v = (1-x)·v<sub>f</sub> + x·v<sub>g</sub></p>
# <p>v = v<sub>f</sub> - x·v<sub>f</sub> + x·v<sub>g</sub></p>
# <p>v = v<sub>f</sub> + x·(v<sub>g</sub> - v<sub>f</sub>)</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 4: Solve for x</p>
# <p>x = (v - v<sub>f</sub>) / (v<sub>g</sub> - v<sub>f</sub>)</p>
# <p>x = (0.24 - 0.001044) / (1.6729 - 0.001044)</p>
# <p>x = 0.238956 / 1.671856</p>
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">x = 0.143 or 14.3% ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Interpretation:</p>
# <p>14.3% of the mass is vapor, 85.7% is liquid</p>
# </div>
#
# <p style="color: #a371f7; margin-top: 15px; font-weight: bold;">🎯 Alternative Formula (easier to remember):</p>
# <p style="background-color: #161b22; padding: 10px; border-radius: 5px;">x = (v - v<sub>f</sub>) / v<sub>fg</sub>, where v<sub>fg</sub> = v<sub>g</sub> - v<sub>f</sub></p>
# </div>
# </details>
#
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #3fb950; border-radius: 8px;">
# <h2 style="color: #3fb950; margin:0;">📗 SECTION 2: Steam Tables & Properties</h2>
# <p style="color: #8b949e; margin-top:5px;">From Part 2 - Property Retrieval</p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #3fb950; margin-top: 20px;">
# <h3 style="color: #3fb950; margin-top:0;">🎯 Problem 2.1: Using Quality Formula</h3>
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; margin-top: 10px;">
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# A mixture of saturated liquid and saturated vapor of water at 100°C has a quality of 0.6.
# </p>
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# <strong>Find:</strong> The specific enthalpy (h) of the mixture.
# </p>
# <p style="color: #8b949e; font-style: italic;">
# Given: At 100°C, h<sub>f</sub> = 419.04 kJ/kg, h<sub>g</sub> = 2676.0 kJ/kg
# </p>
# </div>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #d29922;">
# <summary style="color: #d29922; font-weight: bold; cursor: pointer; font-size: 16px;">💡 Click here for Hint</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p><strong>Hint:</strong></p>
# <p>This is a direct application of the quality formula!</p>
# <p>h = (1-x)·h<sub>f</sub> + x·h<sub>g</sub></p>
# <p>Just plug in x = 0.6 and the given values!</p>
# </div>
# </details>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #3fb950;">
# <summary style="color: #3fb950; font-weight: bold; cursor: pointer; font-size: 16px;">✅ Click here for Full Solution</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">Solution:</p>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Given:</p>
# <ul>
# <li>Quality, x = 0.6</li>
# <li>h<sub>f</sub> = 419.04 kJ/kg</li>
# <li>h<sub>g</sub> = 2676.0 kJ/kg</li>
# </ul>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Apply quality formula:</p>
# <p>h = (1-x)·h<sub>f</sub> + x·h<sub>g</sub></p>
# <p>h = (1-0.6) × 419.04 + 0.6 × 2676.0</p>
# <p>h = 0.4 × 419.04 + 0.6 × 2676.0</p>
# <p>h = 167.616 + 1605.6</p>
# <p style="color: #3fb950; font-weight: bold; font-size: 20px;">h = 1773.22 kJ/kg ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Verification:</p>
# <p>Does our answer make sense?</p>
# <p>h<sub>f</sub> (419.04) < h (1773.22) < h<sub>g</sub> (2676.0) ✅</p>
# <p style="color: #3fb950;">Yes! The mixture enthalpy is between liquid and vapor values!</p>
# </div>
#
# <p style="color: #a371f7; margin-top: 15px; font-weight: bold;">🎯 Alternative Method:</p>
# <p style="background-color: #161b22; padding: 10px; border-radius: 5px;">
# h = h<sub>f</sub> + x·h<sub>fg</sub>, where h<sub>fg</sub> = h<sub>g</sub> - h<sub>f</sub> = 2256.96 kJ/kg<br>
# h = 419.04 + 0.6 × 2256.96 = 419.04 + 1354.18 = 1773.22 kJ/kg ✅
# </p>
# </div>
# </details>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #3fb950; margin-top: 20px;">
# <h3 style="color: #3fb950; margin-top:0;">🎯 Problem 2.2: Subcooled Liquid Approximation</h3>
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; margin-top: 10px;">
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# Water is at 80°C and 5 bar (subcooled liquid). Estimate the specific enthalpy using the subcooled liquid approximation.
# </p>
# <p style="color: #8b949e; font-style: italic;">
# Given: At 80°C, h<sub>f</sub> = 334.9 kJ/kg, v<sub>f</sub> = 0.001029 m³/kg, p<sub>sat</sub> = 0.4736 bar
# </p>
# </div>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #d29922;">
# <summary style="color: #d29922; font-weight: bold; cursor: pointer; font-size: 16px;">💡 Click here for Hint</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p><strong>Hints:</strong></p>
# <ol>
# <li>Use the approximation: h(T,p) ≈ h<sub>f</sub>(T) + v<sub>f</sub>(T)·[p - p<sub>sat</sub>(T)]</li>
# <li>Make sure units are consistent!</li>
# <li>Convert pressure to Pa if needed (1 bar = 10⁵ Pa)</li>
# </ol>
# </div>
# </details>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #3fb950;">
# <summary style="color: #3fb950; font-weight: bold; cursor: pointer; font-size: 16px;">✅ Click here for Full Solution</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">Solution:</p>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Given:</p>
# <ul>
# <li>T = 80°C, p = 5 bar</li>
# <li>h<sub>f</sub>(80°C) = 334.9 kJ/kg</li>
# <li>v<sub>f</sub>(80°C) = 0.001029 m³/kg</li>
# <li>p<sub>sat</sub>(80°C) = 0.4736 bar</li>
# </ul>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 1: Apply approximation formula</p>
# <p>h(T,p) ≈ h<sub>f</sub>(T) + v<sub>f</sub>(T)·[p - p<sub>sat</sub>(T)]</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 2: Convert units (optional but good practice)</p>
# <p>p = 5 bar = 5 × 10⁵ Pa</p>
# <p>p<sub>sat</sub> = 0.4736 bar = 0.4736 × 10⁵ Pa</p>
# <p>v<sub>f</sub> = 0.001029 m³/kg</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 3: Calculate correction term</p>
# <p>v<sub>f</sub>·[p - p<sub>sat</sub>] = 0.001029 × [(5 - 0.4736) × 10⁵]</p>
# <p>= 0.001029 × 4.5264 × 10⁵</p>
# <p>= 465.77 J/kg</p>
# <p>= 0.466 kJ/kg</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 4: Calculate h</p>
# <p>h ≈ h<sub>f</sub> + correction</p>
# <p>h ≈ 334.9 + 0.466</p>
# <p style="color: #3fb950; font-weight: bold; font-size: 20px;">h ≈ 335.37 kJ/kg ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Observation:</p>
# <p>The correction term (0.466 kJ/kg) is VERY SMALL compared to h<sub>f</sub> (334.9 kJ/kg)</p>
# <p style="color: #3fb950;">This shows liquids are nearly incompressible! Pressure change has minimal effect on h!</p>
# </div>
#
# <p style="color: #a371f7; margin-top: 15px; font-weight: bold;">🎯 Simplified Approximation:</p>
# <p style="background-color: #161b22; padding: 10px; border-radius: 5px;">
# For quick estimates, you can often just use: h ≈ h<sub>f</sub>(T) = 334.9 kJ/kg<br>
# Error ≈ 0.14% (negligible!)
# </p>
# </div>
# </details>
#
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #d29922; border-radius: 8px;">
# <h2 style="color: #d29922; margin:0;">📙 SECTION 3: Ideal Gas Problems</h2>
# <p style="color: #8b949e; margin-top:5px;">From Part 3 - Ideal Gas Applications</p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #d29922; margin-top: 20px;">
# <h3 style="color: #3fb950; margin-top:0;">🎯 Problem 3.1: Ideal Gas Equation</h3>
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; margin-top: 10px;">
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# A rigid tank contains 2 kg of air at 300 K and 200 kPa.
# </p>
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# <strong>Find:</strong> The volume of the tank.
# </p>
# <p style="color: #8b949e; font-style: italic;">
# Given: For air, R = 0.287 kJ/(kg·K)
# </p>
# </div>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #d29922;">
# <summary style="color: #d29922; font-weight: bold; cursor: pointer; font-size: 16px;">💡 Click here for Hint</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p><strong>Hints:</strong></p>
# <ol>
# <li>Use ideal gas equation in extensive form: pV = MRT</li>
# <li>Solve for V</li>
# <li>Watch the units! Convert kPa to Pa if needed</li>
# </ol>
# </div>
# </details>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #3fb950;">
# <summary style="color: #3fb950; font-weight: bold; cursor: pointer; font-size: 16px;">✅ Click here for Full Solution</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">Solution:</p>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Given:</p>
# <ul>
# <li>Mass, M = 2 kg</li>
# <li>Temperature, T = 300 K</li>
# <li>Pressure, p = 200 kPa = 200 × 10³ Pa</li>
# <li>Gas constant for air, R = 0.287 kJ/(kg·K) = 287 J/(kg·K)</li>
# </ul>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 1: Write ideal gas equation (extensive form)</p>
# <p>pV = MRT</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 2: Solve for V</p>
# <p>V = MRT / p</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 3: Substitute values</p>
# <p>V = (2 kg) × (287 J/(kg·K)) × (300 K) / (200 × 10³ Pa)</p>
# <p>V = (2 × 287 × 300) / (200 × 10³)</p>
# <p>V = 172,200 / 200,000</p>
# <p style="color: #3fb950; font-weight: bold; font-size: 20px;">V = 0.861 m³ ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Alternative: Using intensive form</p>
# <p>pv = RT → v = RT/p</p>
# <p>v = (287 × 300) / (200 × 10³) = 0.4305 m³/kg</p>
# <p>V = M × v = 2 × 0.4305 = 0.861 m³ ✅</p>
# </div>
#
# <p style="color: #a371f7; margin-top: 15px; font-weight: bold;">🎯 Key Takeaway:</p>
# <p style="background-color: #161b22; padding: 10px; border-radius: 5px;">
# Always check units! R in kJ/(kg·K) needs p in kPa, or R in J/(kg·K) needs p in Pa.
# </p>
# </div>
# </details>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #d29922; margin-top: 20px;">
# <h3 style="color: #3fb950; margin-top:0;">🎯 Problem 3.2: Specific Heats and Internal Energy</h3>
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; margin-top: 10px;">
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# Air (treated as ideal gas) is heated from 300 K to 400 K at constant volume. Calculate the change in specific internal energy.
# </p>
# <p style="color: #8b949e; font-style: italic;">
# Given: For air, c<sub>v</sub> = 0.718 kJ/(kg·K) (assume constant)
# </p>
# </div>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #d29922;">
# <summary style="color: #d29922; font-weight: bold; cursor: pointer; font-size: 16px;">💡 Click here for Hint</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p><strong>Hints:</strong></p>
# <ol>
# <li>For ideal gas, u = u(T) only</li>
# <li>At constant volume: δq = du = c<sub>v</sub>·dT</li>
# <li>For constant c<sub>v</sub>: Δu = c<sub>v</sub>·ΔT</li>
# </ol>
# </div>
# </details>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #3fb950;">
# <summary style="color: #3fb950; font-weight: bold; cursor: pointer; font-size: 16px;">✅ Click here for Full Solution</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">Solution:</p>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Given:</p>
# <ul>
# <li>Initial temperature, T₁ = 300 K</li>
# <li>Final temperature, T₂ = 400 K</li>
# <li>c<sub>v</sub> = 0.718 kJ/(kg·K)</li>
# <li>Process: Constant volume</li>
# </ul>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 1: Key concept for ideal gas</p>
# <p>For ideal gas, internal energy depends ONLY on temperature: u = u(T)</p>
# <p style="color: #3fb950;">This is true regardless of whether volume is constant or not!</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 2: Relationship between Δu and c<sub>v</sub></p>
# <p>c<sub>v</sub> = du/dT (for ideal gas)</p>
# <p>For constant c<sub>v</sub>:</p>
# <p>Δu = ∫c<sub>v</sub>·dT = c<sub>v</sub>·ΔT</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 3: Calculate ΔT</p>
# <p>ΔT = T₂ - T₁ = 400 - 300 = 100 K</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 4: Calculate Δu</p>
# <p>Δu = c<sub>v</sub> × ΔT</p>
# <p>Δu = 0.718 × 100</p>
# <p style="color: #3fb950; font-weight: bold; font-size: 20px;">Δu = 71.8 kJ/kg ✅</p>
# </div>
#
# <p style="color: #a371f7; margin-top: 15px; font-weight: bold;">🎯 Important Note:</p>
# <p style="background-color: #161b22; padding: 10px; border-radius: 5px;">
# Even though the problem says "constant volume", for ideal gas Δu = c<sub>v</sub>·ΔT works for ANY process! <br>
# Because u = u(T) only for ideal gas.<br><br>
# Constant volume just means: Q = Δu (no work done)
# </p>
# </div>
# </details>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #d29922; margin-top: 20px;">
# <h3 style="color: #3fb950; margin-top:0;">🎯 Problem 3.3: The Golden Relation (c<sub>p</sub> = c<sub>v</sub> + R)</h3>
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; margin-top: 10px;">
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# For air, c<sub>v</sub> = 0.718 kJ/(kg·K) and R = 0.287 kJ/(kg·K).
# </p>
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# <strong>Find:</strong>
# </p>
# <ol style="color: #c9d1d9; line-height: 1.8;">
# <li>c<sub>p</sub> using the relation c<sub>p</sub> = c<sub>v</sub> + R</li>
# <li>The specific heat ratio γ = c<sub>p</sub>/c<sub>v</sub></li>
# <li>Verify if this matches the theoretical value for diatomic gases</li>
# </ol>
# </div>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #d29922;">
# <summary style="color: #d29922; font-weight: bold; cursor: pointer; font-size: 16px;">💡 Click here for Hint</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p><strong>Hints:</strong></p>
# <ol>
# <li>Part 1: Direct substitution in c<sub>p</sub> = c<sub>v</sub> + R</li>
# <li>Part 2: γ = c<sub>p</sub>/c<sub>v</sub></li>
# <li>Part 3: For rigid diatomic (5 modes), theoretical γ = 7/5 = 1.4</li>
# </ol>
# </div>
# </details>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #3fb950;">
# <summary style="color: #3fb950; font-weight: bold; cursor: pointer; font-size: 16px;">✅ Click here for Full Solution</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">Solution:</p>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Given:</p>
# <ul>
# <li>c<sub>v</sub> = 0.718 kJ/(kg·K)</li>
# <li>R = 0.287 kJ/(kg·K)</li>
# </ul>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Part 1: Calculate c<sub>p</sub></p>
# <p>Using the golden relation:</p>
# <p>c<sub>p</sub> = c<sub>v</sub> + R</p>
# <p>c<sub>p</sub> = 0.718 + 0.287</p>
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">c<sub>p</sub> = 1.005 kJ/(kg·K) ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Part 2: Calculate γ</p>
# <p>γ = c<sub>p</sub> / c<sub>v</sub></p>
# <p>γ = 1.005 / 0.718</p>
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">γ = 1.40 ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Part 3: Theoretical verification</p>
# <p>Air is mostly N₂ (78%) and O₂ (21%) - both DIATOMIC molecules</p>
# <p>For rigid diatomic gas (5 modes: 3 translational + 2 rotational):</p>
# <p>Theoretical γ = 7/5 = 1.4</p>
# <p style="color: #3fb950; font-weight: bold;">Our calculated value (1.40) PERFECTLY matches theory! ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Why this works:</p>
# <p>At normal temperatures, vibrational modes are NOT excited in air</p>
# <p>So air behaves as rigid diatomic with 5 degrees of freedom</p>
# <p>c<sub>v</sub> = (5/2)R = 2.5 × 0.287 = 0.7175 ≈ 0.718 kJ/(kg·K) ✅</p>
# <p>c<sub>p</sub> = (7/2)R = 3.5 × 0.287 = 1.0045 ≈ 1.005 kJ/(kg·K) ✅</p>
# </div>
#
# <p style="color: #a371f7; margin-top: 15px; font-weight: bold;">🎯 Key Takeaway:</p>
# <p style="background-color: #161b22; padding: 10px; border-radius: 5px;">
# The golden relation c<sub>p</sub> = c<sub>v</sub> + R is SUPER useful!<br>
# Know any two of {c<sub>p</sub>, c<sub>v</sub>, R} and you can find the third!<br>
# For air: γ = 1.4 is the magic number to remember! 🎯
# </p>
# </div>
# </details>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #d29922; margin-top: 20px;">
# <h3 style="color: #3fb950; margin-top:0;">🎯 Problem 3.4: Equipartition Model</h3>
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; margin-top: 10px;">
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# Calculate c<sub>v</sub>, c<sub>p</sub>, and γ for:
# </p>
# <ol style="color: #c9d1d9; line-height: 1.8;">
# <li>Helium (He) - monatomic gas</li>
# <li>Hydrogen (H₂) - diatomic gas at room temperature (rigid)</li>
# </ol>
# <p style="color: #8b949e; font-style: italic;">
# Given: Universal gas constant R̂ = 8.314 J/(mol·K)<br>
# Molar mass: He = 4 g/mol, H₂ = 2 g/mol
# </p>
# </div>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #d29922;">
# <summary style="color: #d29922; font-weight: bold; cursor: pointer; font-size: 16px;">💡 Click here for Hint</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p><strong>Hints:</strong></p>
# <ol>
# <li>First calculate R = R̂/M̂ for each gas</li>
# <li>For monatomic: 3 modes → c<sub>v</sub> = (3/2)R, c<sub>p</sub> = (5/2)R</li>
# <li>For rigid diatomic: 5 modes → c<sub>v</sub> = (5/2)R, c<sub>p</sub> = (7/2)R</li>
# <li>γ = c<sub>p</sub>/c<sub>v</sub></li>
# </ol>
# </div>
# </details>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #3fb950;">
# <summary style="color: #3fb950; font-weight: bold; cursor: pointer; font-size: 16px;">✅ Click here for Full Solution</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">Solution:</p>
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #d29922; font-weight: bold; font-size: 16px;">Part 1: Helium (Monatomic)</p>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 1: Calculate R for Helium</p>
# <p>R = R̂ / M̂ = 8.314 / 0.004 = 2078.5 J/(kg·K) = 2.0785 kJ/(kg·K)</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 2: Apply equipartition (3 modes)</p>
# <p>Monatomic: 3 translational modes only</p>
# <p>c<sub>v</sub> = (3/2)R = 1.5 × 2.0785 = <strong style="color: #3fb950;">3.118 kJ/(kg·K) ✅</strong></p>
# <p>c<sub>p</sub> = c<sub>v</sub> + R = 3.118 + 2.0785 = <strong style="color: #3fb950;">5.197 kJ/(kg·K) ✅</strong></p>
# <p>OR: c<sub>p</sub> = (5/2)R = 2.5 × 2.0785 = 5.197 kJ/(kg·K) ✅</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 3: Calculate γ</p>
# <p>γ = c<sub>p</sub>/c<sub>v</sub> = 5.197/3.118 = <strong style="color: #3fb950;">1.667 ✅</strong></p>
# <p>OR: γ = (5/2)R / (3/2)R = 5/3 = 1.667 ✅</p>
# </div>
# </div>
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 5px; margin-top: 15px;">
# <p style="color: #d29922; font-weight: bold; font-size: 16px;">Part 2: Hydrogen (Rigid Diatomic)</p>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 1: Calculate R for H₂</p>
# <p>R = R̂ / M̂ = 8.314 / 0.002 = 4157 J/(kg·K) = 4.157 kJ/(kg·K)</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 2: Apply equipartition (5 modes)</p>
# <p>Rigid diatomic: 3 translational + 2 rotational = 5 modes</p>
# <p>c<sub>v</sub> = (5/2)R = 2.5 × 4.157 = <strong style="color: #3fb950;">10.39 kJ/(kg·K) ✅</strong></p>
# <p>c<sub>p</sub> = c<sub>v</sub> + R = 10.39 + 4.157 = <strong style="color: #3fb950;">14.55 kJ/(kg·K) ✅</strong></p>
# <p>OR: c<sub>p</sub> = (7/2)R = 3.5 × 4.157 = 14.55 kJ/(kg·K) ✅</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Step 3: Calculate γ</p>
# <p>γ = c<sub>p</sub>/c<sub>v</sub> = 14.55/10.39 = <strong style="color: #3fb950;">1.40 ✅</strong></p>
# <p>OR: γ = (7/2)R / (5/2)R = 7/5 = 1.4 ✅</p>
# </div>
# </div>
#
# <div style="background-color: #161b22; padding: 15px; border-radius: 5px; margin-top: 15px;">
# <p style="color: #58a6ff; font-weight: bold;">Summary Table:</p>
# <table style="width:100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #0d1117;">
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Gas</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">R (kJ/kg·K)</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">c<sub>v</sub></th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">c<sub>p</sub></th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">γ</th>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">He</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">2.079</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">3.118</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">5.197</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">1.667</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">H₂</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">4.157</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">10.39</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">14.55</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">1.40</td>
# </tr>
# </table>
# </div>
#
# <p style="color: #a371f7; margin-top: 15px; font-weight: bold;">🎯 Key Observations:</p>
# <ul style="background-color: #161b22; padding: 15px; border-radius: 5px; line-height: 1.8;">
# <li>Lighter molecules (smaller M̂) have larger R!</li>
# <li>Monatomic γ (1.667) > Diatomic γ (1.4)</li>
# <li>More modes = Lower γ (energy distributed over more ways)</li>
# <li>The equipartition model works beautifully! 🎯</li>
# </ul>
# </div>
# </details>
#
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #a371f7; border-radius: 8px;">
# <h2 style="color: #a371f7; margin:0;">📕 SECTION 4: Mixed Concepts (Challenge!)</h2>
# <p style="color: #8b949e; margin-top:5px;">Combining Multiple Parts - Test Your Understanding!</p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #a371f7; margin-top: 20px;">
# <h3 style="color: #3fb950; margin-top:0;">🎯 Problem 4.1: Comprehensive Problem</h3>
# <div style="background-color: #0d1117; padding: 15px; border-radius: 8px; margin-top: 10px;">
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# A piston-cylinder device contains 3 kg of steam at 200°C and 400 kPa.
# </p>
# <p style="color: #c9d1d9; font-size: 16px; line-height: 1.8;">
# <strong>Determine:</strong>
# </p>
# <ol style="color: #c9d1d9; line-height: 1.8;">
# <li>The state (subcooled, saturated, two-phase, or superheated)</li>
# <li>The specific volume</li>
# <li>Compare with ideal gas assumption (R for water = 0.4615 kJ/kg·K)</li>
# </ol>
# <p style="color: #8b949e; font-style: italic;">
# Given: At 400 kPa, T<sub>sat</sub> = 143.6°C, v<sub>g</sub> = 0.4625 m³/kg<br>
# At 200°C and 400 kPa (superheated): v = 0.5342 m³/kg
# </p>
# </div>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #d29922;">
# <summary style="color: #d29922; font-weight: bold; cursor: pointer; font-size: 16px;">💡 Click here for Hint</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p><strong>Hints:</strong></p>
# <ol>
# <li>Part 1: Compare T with T<sub>sat</sub> at given pressure</li>
# <li>Part 2: If superheated, use superheated steam table value</li>
# <li>Part 3: Calculate v using ideal gas: v = RT/p, then compare!</li>
# </ol>
# </div>
# </details>
#
# <details style="margin-top: 15px; background-color: #0d1117; padding: 15px; border-radius: 8px; border-left: 4px solid #3fb950;">
# <summary style="color: #3fb950; font-weight: bold; cursor: pointer; font-size: 16px;">✅ Click here for Full Solution</summary>
# <div style="margin-top: 10px; color: #c9d1d9; line-height: 1.8;">
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">Solution:</p>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Part 1: Identify the state</p>
# <p>Given: T = 200°C, p = 400 kPa</p>
# <p>At p = 400 kPa, T<sub>sat</sub> = 143.6°C</p>
# <p>Since T (200°C) > T<sub>sat</sub> (143.6°C)</p>
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">State: SUPERHEATED VAPOR ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Part 2: Specific volume from steam tables</p>
# <p>From superheated steam table at 200°C and 400 kPa:</p>
# <p style="color: #3fb950; font-weight: bold; font-size: 18px;">v = 0.5342 m³/kg ✅</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Part 3: Ideal gas approximation</p>
# <p>Using pv = RT:</p>
# <p>v = RT/p</p>
# <p>v = (0.4615 kJ/kg·K × (200 + 273.15) K) / (400 kPa)</p>
# <p>v = (0.4615 × 473.15) / 400</p>
# <p>v = 218.35 / 400</p>
# <p style="color: #3fb950; font-weight: bold;">v<sub>ideal</sub> = 0.5459 m³/kg</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Comparison:</p>
# <p>Actual (from tables): v = 0.5342 m³/kg</p>
# <p>Ideal gas: v = 0.5459 m³/kg</p>
# <p>Error = |0.5459 - 0.5342| / 0.5342 × 100% = 2.2%</p>
# <p style="color: #3fb950; font-weight: bold;">The ideal gas approximation is quite good! (Only 2.2% error) ✅</p>
# </div>
#
# <p style="color: #a371f7; margin-top: 15px; font-weight: bold;">🎯 Key Takeaways:</p>
# <ul style="background-color: #161b22; padding: 15px; border-radius: 5px; line-height: 1.8;">
# <li>At low pressure (400 kPa) and high temperature (200°C), steam behaves nearly as ideal gas</li>
# <li>For accurate work, always use steam tables!</li>
# <li>Ideal gas is good for quick estimates when far from saturation</li>
# </ul>
# </div>
# </details>
#
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 25px; border-radius: 10px; text-align: center; margin-top: 30px;">
# <h2 style="color: #ffffff; margin: 0;">🎉 CONGRATULATIONS! 🎉</h2>
# <p style="color: #ffffff; margin-top: 15px; font-size: 18px;">
# You've completed ALL 4 PARTS of Properties of Pure Substance! 💪
# </p>
# <div style="background-color: rgba(255,255,255,0.1); padding: 15px; border-radius: 8px; margin-top: 20px;">
# <p style="color: #ffeb3b; font-weight: bold; font-size: 20px; margin: 0;">What You've Mastered:</p>
# <ul style="color: #ffffff; text-align: left; line-height: 2.0; margin-top: 10px; font-size: 16px;">
# <li>✅ Phase diagrams & identifying states</li>
# <li>✅ Quality calculations for mixtures</li>
# <li>✅ Reading and using steam tables like a pro</li>
# <li>✅ Subcooled liquid approximations</li>
# <li>✅ Ideal gas equation and applications</li>
# <li>✅ Specific heats and the golden relation</li>
# <li>✅ Equipartition model for gases</li>
# <li>✅ Solving complex mixed problems</li>
# </ul>
# </div>
# <p style="color: #ffffff; margin-top: 20px; font-size: 16px;">
# Keep practicing these problems and you'll ACE your exams! 🚀
# </p>
# <p style="color: #ffeb3b; margin-top: 15px; font-size: 18px; font-weight: bold;">
# Remember: Practice makes perfect! 🎯
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 20px; border-radius: 10px; border: 2px solid #3fb950; margin-top: 20px;">
# <h3 style="color: #3fb950; margin-top:0;">📚 Additional Practice Tips</h3>
# <ul style="color: #c9d1d9; line-height: 1.8; font-size: 16px;">
# <li>🎯 Redo these problems without looking at solutions</li>
# <li>🎯 Try variations: change values, ask different questions</li>
# <li>🎯 Practice reading steam tables - get comfortable with interpolation</li>
# <li>🎯 Memorize key values: γ = 1.4 for air, c<sub>p</sub> = c<sub>v</sub> + R</li>
# <li>🎯 Draw diagrams for every problem - visualize the process!</li>
# <li>🎯 Check your answers: Do they make physical sense?</li>
# <li>🎯 Compare different methods: tables vs ideal gas</li>
# </ul>
# <p style="color: #3fb950; font-weight: bold; margin-top: 15px; font-size: 18px;">
# You've got this, bro! Keep crushing it! 💪🔥
# </p>
# </div>
