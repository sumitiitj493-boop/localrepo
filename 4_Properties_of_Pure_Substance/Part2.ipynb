# %% [markdown]
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 20px; border-left: 5px solid #3fb950; border-radius: 8px;">
# <h1 style="color: #c9d1d9; margin:0;">🎯 Properties of Pure Substance - PART 2</h1>
# <p style="color: #8b949e; margin-top:5px;">Chapter 4 | Now Let's Get Practical - Tables, Numbers & Real Calculations! 🔥</p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h2 style="color: #58a6ff; margin-top:0;">📚 In This Part</h2>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>How to <strong>read Steam Tables</strong> like a pro! 📊</li>
# <li>The magical <strong>Quality Formula</strong> for mixtures</li>
# <li>Temperature vs Pressure tables (and which one to use when)</li>
# <li>Tricks for <strong>Subcooled Liquid</strong> properties</li>
# <li><strong>Derivative Properties</strong> - Compressibilities & Specific Heats</li>
# <li>Why <strong>Enthalpy</strong> is the real MVP! 🏆</li>
# <li><strong>Incompressible Substances</strong> - The simplest case ever!</li>
# </ul>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #58a6ff; border-radius: 8px;">
# <h2 style="color: #58a6ff; margin:0;">📖 4.5 Retrieving Thermodynamic Properties</h2>
# <p style="color: #8b949e; margin-top:5px;">Time to become a Table-Reading Ninja! 🥷</p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #d29922;">
# <strong style="color: #d29922;">⚠️ SUPER IMPORTANT WARNING!</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Properties like <strong>internal energy (u), specific volume (v), enthalpy (h), entropy (s)</strong> can be found using:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>📊 Tables</li>
# <li>📈 Graphs/Charts</li>
# <li>📐 Equations</li>
# <li>💻 Computer Software</li>
# </ul>
# <p style="color: #f85149; font-weight: bold; margin-top: 15px; font-size: 16px;">
# 🚫 Never use software as a BLACKBOX! 🚫
# </p>
# <p style="color: #c9d1d9;">
# You MUST understand tables and diagrams first, otherwise you'll make wrong calculations and design faulty thermal equipment! 💥
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Real-Life Analogy</h3>
# <p style="color: #c9d1d9;">
# Using software without understanding tables is like:
# </p>
# <p style="color: #c9d1d9;">
# ❌ Using Google Maps without knowing North-South-East-West<br>
# ❌ Copying code from StackOverflow without understanding it<br>
# ❌ Using a calculator without knowing basic math
# </p>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px;">
# You'll be lost the moment something goes wrong! 😵
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 METHOD 1: Superheated Vapor Tables</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# For superheated vapor states (after state 'g'), we use superheated vapor tables.
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🎯 How Superheated Vapor Tables are Organized</h3>
# <p style="color: #c9d1d9;">
# The table is organized by <strong>PRESSURE</strong> (each pressure gets its own section).
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# For each pressure:
# </p>
# <ol style="color: #c9d1d9; line-height: 1.8;">
# <li>First row = <strong>Saturated vapor state (g)</strong> at that pressure</li>
# <li>Following rows = <strong>Increasing temperatures</strong> (superheated states)</li>
# <li>Properties given: T, v, u, h, s (and sometimes more)</li>
# </ol>
# </div>

# %% [markdown]
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; background: #0d1117; padding: 20px; border-radius: 8px; border: 1px solid #30363d; color: #c9d1d9; line-height: 1.2;">
#   SUPERHEATED VAPOR TABLE STRUCTURE (Example)
#
#   ┌─────────────────────────────────────────────────┐
#   │  Pressure = 10 bar                              │
#   ├──────┬────────┬────────┬────────┬──────────────┤
#   │  T   │   v    │   u    │   h    │      s       │
#   │ (°C) │ (m³/kg)│ (kJ/kg)│ (kJ/kg)│  (kJ/kg·K)   │
#   ├──────┼────────┼────────┼────────┼──────────────┤
#   │ Sat. │ 0.1944 │ 2583.6 │ 2778.1 │   6.5865     │ <- g
#   │ 200  │ 0.2060 │ 2621.9 │ 2827.9 │   6.6940     │
#   │ 250  │ 0.2327 │ 2709.9 │ 2942.6 │   6.9247     │
#   │ 300  │ 0.2579 │ 2793.2 │ 3051.2 │   7.1229     │
#   │ 350  │ 0.2825 │ 2875.0 │ 3157.7 │   7.3011     │
#   └──────┴────────┴────────┴────────┴──────────────┘
#
#   ┌─────────────────────────────────────────────────┐
#   │  Pressure = 50 bar                              │
#   ├──────┬────────┬────────┬────────┬──────────────┤
#   │  T   │   v    │   u    │   h    │      s       │
#   ├──────┼────────┼────────┼────────┼──────────────┤
#   │ Sat. │ 0.0394 │ 2561.2 │ 2748.0 │   5.9734     │ <- g
#   │ 300  │ 0.0453 │ 2699.2 │ 2925.9 │   6.2120     │
#   │ 350  │ 0.0503 │ 2789.1 │ 3040.4 │   6.4085     │
#   └──────┴────────┴────────┴────────┴──────────────┘
#
#   Key Points:
#   - Each pressure = One isobar
#   - First row = Saturated vapor (starting point)
#   - p & T are INDEPENDENT here (can use both to fix state)
# </pre>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 How to Use Superheated Vapor Tables</h3>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Step 1: Know your Pressure</p>
# <p style="color: #c9d1d9;">Find the section corresponding to your pressure</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Step 2: Know your Temperature</p>
# <p style="color: #c9d1d9;">Find the row corresponding to your temperature</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Step 3: Read the Properties</p>
# <p style="color: #c9d1d9;">At the intersection, read v, u, h, s values</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #f85149; font-weight: bold;">Step 4: Linear Interpolation (if needed)</p>
# <p style="color: #c9d1d9;">If your exact p or T is not in table, interpolate between adjacent values!</p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">✅ KEY INSIGHT: Why p & T?</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# In the <strong>single-phase region</strong> (superheated vapor), pressure and temperature are <strong>INDEPENDENT</strong> properties.
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# So we can use <strong>p and T together</strong> to "fix the state"! That's why tables are organized this way.
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 METHOD 2: Saturated Mixture Tables (The Quality Game!)</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# For two-phase liquid-vapor mixtures (between f and g), we use saturated tables.
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🎯 The Challenge</h3>
# <p style="color: #c9d1d9;">
# In saturation mixture:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Some mass = Saturated liquid</li>
# <li>Some mass = Saturated vapor</li>
# <li>All states along an isobar have <strong>SAME T and p</strong></li>
# </ul>
# <p style="color: #d29922; font-weight: bold; margin-top: 10px;">
# Problem: p & T are NOT independent in two-phase region! 😰
# </p>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px;">
# Solution: Use QUALITY (x) to distinguish states! 🎯
# </p>
# </div>

# %% [markdown]
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; background: #0d1117; padding: 20px; border-radius: 8px; border: 1px solid #30363d; color: #c9d1d9; line-height: 1.2;">
#   SATURATED MIXTURE TABLE (Temperature Table Example)
#
#   ┌────┬──────┬──────────────────────────────────────┐
#   │ T  │ psat │    Sat. Liquid  │  Sat. Vapor        │
#   │(°C)│ (bar)│      (f)        │     (g)            │
#   │    │      ├────┬────┬───────┼────┬────┬──────────┤
#   │    │      │ vf │ uf │  hf   │ vg │ ug │   hg     │
#   ├────┼──────┼────┼────┼───────┼────┼────┼──────────┤
#   │ 20 │0.0234│.001│83.9 │ 83.9 │57.8│2402│ 2538.1   │
#   │ 40 │0.0738│.001│167.5│167.6 │19.5│2430│ 2574.3   │
#   │ 60 │0.1992│.001│251.1│251.2 │7.67│2456│ 2609.6   │
#   │ 80 │0.4736│.001│334.9│335.0 │3.41│2482│ 2643.7   │
#   │100 │1.0135│.001│419.0│419.2 │1.67│2506│ 2676.0   │
#   │120 │1.9854│.001│503.7│504.0 │0.89│2529│ 2706.3   │
#   └────┴──────┴────┴────┴───────┴────┴────┴──────────┘
#
#   Key Features:
#   - Each row = One saturation temperature
#   - psat = Corresponding saturation pressure
#   - Two sets of properties: 'f' (liquid) and 'g' (vapor)
#   - ANY state between f and g uses these values + quality
# </pre>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #d29922;">
# <strong style="color: #d29922;">⚡ THE MAGIC FORMULA - Property Calculation for Mixtures</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Let's say total mass of mixture = m<sub>f</sub> + m<sub>g</sub><br>
# We want to find specific internal energy <strong>u</strong> of the mixture.
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">🧮 Step-by-Step Derivation</h3>
#
# <p style="color: #c9d1d9; font-weight: bold; margin-top: 10px;">Step 1: Total Internal Energy</p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #161b22; padding: 10px; border-radius: 5px;">
# U = m<sub>f</sub> · u<sub>f</sub> + m<sub>g</sub> · u<sub>g</sub>
# </p>
#
# <p style="color: #c9d1d9; font-weight: bold; margin-top: 15px;">Step 2: Divide by Total Mass</p>
# <p style="color: #c9d1d9;">
# Divide both sides by (m<sub>f</sub> + m<sub>g</sub>):
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #161b22; padding: 10px; border-radius: 5px;">
# u = [m<sub>f</sub>/(m<sub>f</sub> + m<sub>g</sub>)] · u<sub>f</sub> + [m<sub>g</sub>/(m<sub>f</sub> + m<sub>g</sub>)] · u<sub>g</sub>
# </p>
#
# <p style="color: #c9d1d9; font-weight: bold; margin-top: 15px;">Step 3: Use Quality Definition</p>
# <p style="color: #c9d1d9;">
# We know: x = m<sub>g</sub>/(m<sub>f</sub> + m<sub>g</sub>)<br>
# Therefore: (1 - x) = m<sub>f</sub>/(m<sub>f</sub> + m<sub>g</sub>)
# </p>
#
# <p style="color: #d29922; font-weight: bold; font-size: 18px; margin-top: 15px; text-align: center; background-color: #161b22; padding: 15px; border-radius: 5px; border: 2px solid #d29922;">
# u = (1 - x) · u<sub>f</sub> + x · u<sub>g</sub>
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #a371f7;">
# <strong style="color: #a371f7;">🌟 THE UNIVERSAL QUALITY FORMULA</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# This works for <strong>ANY</strong> intensive property q!
# </p>
# <p style="color: #a371f7; font-weight: bold; font-size: 20px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #a371f7;">
# q = (1 - x) · q<sub>f</sub> + x · q<sub>g</sub>
# </p>
# <p style="color: #c9d1d9; margin-top: 15px;">
# Works for:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>v = (1 - x)·v<sub>f</sub> + x·v<sub>g</sub></li>
# <li>u = (1 - x)·u<sub>f</sub> + x·u<sub>g</sub></li>
# <li>h = (1 - x)·h<sub>f</sub> + x·h<sub>g</sub></li>
# <li>s = (1 - x)·s<sub>f</sub> + x·s<sub>g</sub></li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Trick: Quality Formula</h3>
# <p style="color: #c9d1d9;">
# <strong>"Weighted Average Magic!"</strong>
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Think of it like calculating your semester grade:
# </p>
# <p style="color: #c9d1d9;">
# Final Grade = (Weight of Midsem) × (Midsem Score) + (Weight of Endsem) × (Endsem Score)
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Here:
# </p>
# <ul style="color: #c9d1d9;">
# <li>Weight of liquid = (1 - x)</li>
# <li>Weight of vapor = x</li>
# <li>Liquid contributes q<sub>f</sub>, Vapor contributes q<sub>g</sub></li>
# </ul>
# <p style="color: #8b949e; font-style: italic;">
# It's a weighted average based on mass fractions! 📊
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Example Time!</h3>
# <p style="color: #c9d1d9;">
# Water at 100°C with quality x = 0.4. Find specific enthalpy h.
# </p>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">Given:</p>
# <p style="color: #c9d1d9;">T = 100°C, x = 0.4</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #58a6ff; font-weight: bold;">From Saturated Table at 100°C:</p>
# <p style="color: #c9d1d9;">h<sub>f</sub> = 419.2 kJ/kg (saturated liquid)<br>
# h<sub>g</sub> = 2676.0 kJ/kg (saturated vapor)</p>
# </div>
#
# <div style="background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Solution:</p>
# <p style="color: #c9d1d9;">
# h = (1 - x)·h<sub>f</sub> + x·h<sub>g</sub><br>
# h = (1 - 0.4) × 419.2 + 0.4 × 2676.0<br>
# h = 0.6 × 419.2 + 0.4 × 2676.0<br>
# h = 251.5 + 1070.4<br>
# <strong style="color: #3fb950;">h = 1321.9 kJ/kg</strong>
# </p>
# </div>
#
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# See? The mixture property is between h<sub>f</sub> and h<sub>g</sub>, closer to whichever phase has more mass! 🎯
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 Temperature Table vs Pressure Table</strong>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🤔 Wait, Two Tables for Same Thing?</h3>
# <p style="color: #c9d1d9;">
# Yes! Saturated mixture properties can be presented in two ways:
# </p>
#
# <table style="width:100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #161b22;">
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Type</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">First Column</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Second Column</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">When to Use?</th>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Temperature Table</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Temperature (T)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">p<sub>sat</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">When you know T, need p</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Pressure Table</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Pressure (p)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">T<sub>sat</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">When you know p, need T</td>
# </tr>
# </table>
#
# <p style="color: #3fb950; font-weight: bold; margin-top: 15px;">
# 🎯 Key Insight: Both tables contain THE SAME DATA, just organized differently!
# </p>
# <p style="color: #c9d1d9;">
# If you plot p vs T from both tables, the curves will <strong>exactly overlap</strong>! 📈
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Trick: Which Table to Use?</h3>
# <p style="color: #c9d1d9;">
# <strong>"Use what you're given!"</strong>
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Given Temperature → Use <strong>Temperature Table</strong></li>
# <li>Given Pressure → Use <strong>Pressure Table</strong></li>
# </ul>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# It's like choosing between a phone directory sorted by name vs sorted by number! 📞
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #d29922;">
# <strong style="color: #d29922;">⚠️ METHOD 3: Subcooled Liquid (The Approximation Game!)</strong>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #f85149;">😰 The Problem</h3>
# <p style="color: #c9d1d9;">
# Thermodynamic tables <strong>DON'T</strong> have exhaustive data for subcooled liquid states!
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Especially at <strong>lower pressures</strong>, subcooled liquid properties are missing. 🤷‍♂️
# </p>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px;">
# Solution: Use APPROXIMATIONS based on saturated liquid data! 💡
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 OBSERVATION: Liquid Behavior</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# From experiments, we found that for liquids at fixed temperature:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>Specific volume (v)</strong> changes VERY LITTLE with pressure</li>
# <li><strong>Specific internal energy (u)</strong> changes VERY LITTLE with pressure</li>
# </ul>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px;">
# Translation: v and u depend mainly on T, not much on p! 🎯
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #a371f7;">
# <strong style="color: #a371f7;">🌟 THE APPROXIMATION FORMULAS</strong>
#
# <p style="color: #c9d1d9; margin-top: 15px;">
# For a subcooled liquid at temperature T and pressure p:
# </p>
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 5px; margin-top: 15px;">
# <p style="color: #a371f7; font-weight: bold;">Approximation 1: Specific Volume</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 10px;">
# v(T, p) ≈ v<sub>f</sub>(T)
# </p>
# <p style="color: #8b949e; font-style: italic; margin-top: 5px;">
# Use saturated liquid specific volume at the same temperature!
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 5px; margin-top: 15px;">
# <p style="color: #a371f7; font-weight: bold;">Approximation 2: Specific Internal Energy</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 10px;">
# u(T, p) ≈ u<sub>f</sub>(T)
# </p>
# <p style="color: #8b949e; font-style: italic; margin-top: 5px;">
# Use saturated liquid internal energy at the same temperature!
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 5px; margin-top: 15px;">
# <p style="color: #a371f7; font-weight: bold;">Approximation 3: Specific Enthalpy (Method 1)</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 10px;">
# h(T, p) ≈ u<sub>f</sub>(T) + p·v<sub>f</sub>(T)
# </p>
# <p style="color: #8b949e; font-style: italic; margin-top: 5px;">
# Using h = u + pv definition with approximations!
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 5px; margin-top: 15px;">
# <p style="color: #a371f7; font-weight: bold;">Approximation 4: Specific Enthalpy (Method 2)</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 10px;">
# h(T, p) ≈ h<sub>f</sub>(T) + v<sub>f</sub>(T)·[p - p<sub>sat</sub>(T)]
# </p>
# <p style="color: #8b949e; font-style: italic; margin-top: 5px;">
# Correction term accounts for pressure difference!
# </p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Real-Life Analogy</h3>
# <p style="color: #c9d1d9;">
# Think of liquids as <strong>stubborn people</strong>! 😄
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Even if you apply a lot of <strong>pressure</strong> (literally!), they don't change their <strong>volume</strong> or <strong>energy</strong> much.
# </p>
# <p style="color: #c9d1d9;">
# But change the <strong>temperature</strong>? Now they respond! 🌡️
# </p>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# That's why we approximate using saturated liquid values at the SAME temperature!
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #d29922; border-radius: 8px;">
# <h2 style="color: #d29922; margin:0;">🔬 4.6 Derivative Properties (The Advanced Stuff!)</h2>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 CONCEPT: Secondary Properties</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# <strong>Derivatives</strong> of thermodynamic properties with respect to other properties are <strong>themselves thermodynamic properties</strong>!
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# These are called <strong>secondary properties</strong> or <strong>derivative properties</strong>.
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🎯 Starting Point: v(T, p)</h3>
# <p style="color: #c9d1d9;">
# Think of specific volume as a function of temperature and pressure: <strong>v(T, p)</strong>
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Using chain rule of calculus, the total differential is:
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #161b22; padding: 15px; border-radius: 5px; margin-top: 10px;">
# dv(T, p) = (∂v/∂T)<sub>p</sub> dT + (∂v/∂p)<sub>T</sub> dp
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Understanding the Partial Derivatives</h3>
#
# <table style="width:100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #0d1117;">
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Derivative</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Meaning</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Geometric Interpretation</th>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">(∂v/∂T)<sub>p</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Rate of change of v with T at constant p</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Slope of isobar on v-T plot</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">(∂v/∂p)<sub>T</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Rate of change of v with p at constant T</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Slope of isotherm on v-p plot</td>
# </tr>
# </table>
#
# </div>

# %% [markdown]
# ---
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 PROPERTY 1: Isobaric Compressibility (β)</strong>
#
# <p style="color: #a371f7; font-weight: bold; font-size: 18px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px;">
# β = (1/v) · (∂v/∂T)<sub>p</sub>
# </p>
#
# <p style="color: #c9d1d9; margin-top: 10px;">
# <strong>Physical Meaning:</strong> Percentage volume increase per unit of temperature increase at constant pressure
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Real-Life Example</h3>
# <p style="color: #c9d1d9;">
# If β = 0.001 K⁻¹:
# </p>
# <p style="color: #c9d1d9;">
# → For every 1 K increase in temperature (at constant pressure), volume increases by 0.1%
# </p>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# This is why thermometers work! Mercury/alcohol expands with temperature! 🌡️
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 PROPERTY 2: Isothermal Compressibility (κ)</strong>
#
# <p style="color: #a371f7; font-weight: bold; font-size: 18px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px;">
# κ = -(1/v) · (∂v/∂p)<sub>T</sub>
# </p>
#
# <p style="color: #c9d1d9; margin-top: 10px;">
# <strong>Physical Meaning:</strong> Percentage volume DECREASE per unit of pressure increase at constant temperature
# </p>
#
# <p style="color: #d29922; margin-top: 10px;">
# Note the <strong>negative sign</strong>! It's there because when pressure increases, volume decreases (inverse relationship).
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Real-Life Example</h3>
# <p style="color: #c9d1d9;">
# If κ = 10⁻¹⁰ Pa⁻¹ (typical for water):
# </p>
# <p style="color: #c9d1d9;">
# → Water is very <strong>incompressible</strong> (small κ means hard to compress)
# </p>
# <p style="color: #c9d1d9;">
# → Gases have much larger κ (easy to compress)
# </p>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# Try compressing water vs air in a syringe - you'll feel the difference! 💉
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Trick: Compressibilities</h3>
# <p style="color: #c9d1d9;">
# <strong>"β = Born to expand, κ = Kompressed unwillingly"</strong>
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>β (Beta)</strong> - How much it <strong>expands</strong> when heated (positive, natural)</li>
# <li><strong>κ (Kappa)</strong> - How much it <strong>kompresses</strong> when squeezed (negative sign shows resistance)</li>
# </ul>
# </div>

# %% [markdown]
# ---
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">📚 PROPERTY 3: Specific Heat at Constant Volume (c<sub>v</sub>)</strong>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🎯 Starting with u(T, v)</h3>
# <p style="color: #c9d1d9;">
# Think of internal energy as function of T and v: <strong>u(T, v)</strong>
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #161b22; padding: 15px; border-radius: 5px; margin-top: 10px;">
# du = (∂u/∂T)<sub>v</sub> dT + (∂u/∂v)<sub>T</sub> dv
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">✅ DEFINITION: c<sub>v</sub></strong>
#
# <p style="color: #3fb950; font-weight: bold; font-size: 18px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px;">
# c<sub>v</sub> = (∂u/∂T)<sub>v</sub>
# </p>
#
# <p style="color: #c9d1d9; margin-top: 10px;">
# <strong>Name:</strong> Specific Heat at Constant Volume (Isochoric Specific Heat)
# </p>
#
# <p style="color: #c9d1d9; margin-top: 10px;">
# <strong>Physical Meaning:</strong> Energy input as heat, per unit mass, per unit temperature rise, for a constant-volume heating process
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Deriving the Physical Meaning</h3>
#
# <p style="color: #c9d1d9;">
# Consider heating a substance in a <strong>rigid container</strong> (constant volume):
# </p>
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; background: #0d1117; padding: 20px; border-radius: 8px; border: 1px solid #30363d; color: #c9d1d9; line-height: 1.2;">
#   Energy Balance:  δq = du + p·dv
#
#   At constant volume:  dv = 0
#                         ↓
#                    δq = du
#                         ↓
#                    δq = c<sub>v</sub>·dT
# </pre>
#
# <p style="color: #3fb950; font-weight: bold; margin-top: 15px;">
# Interpretation: c<sub>v</sub> tells you how much heat is needed to raise temperature by 1°C when volume is constant!
# </p>
#
# </div>

# %% [markdown]
# ---
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">📚 PROPERTY 4: Specific Heat at Constant Pressure (c<sub>p</sub>)</strong>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🎯 Starting with h(T, p)</h3>
# <p style="color: #c9d1d9;">
# Think of enthalpy as function of T and p: <strong>h(T, p)</strong>
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #161b22; padding: 15px; border-radius: 5px; margin-top: 10px;">
# dh = (∂h/∂T)<sub>p</sub> dT + (∂h/∂p)<sub>T</sub> dp
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">✅ DEFINITION: c<sub>p</sub></strong>
#
# <p style="color: #3fb950; font-weight: bold; font-size: 18px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px;">
# c<sub>p</sub> = (∂h/∂T)<sub>p</sub>
# </p>
#
# <p style="color: #c9d1d9; margin-top: 10px;">
# <strong>Name:</strong> Specific Heat at Constant Pressure (Isobaric Specific Heat)
# </p>
#
# <p style="color: #c9d1d9; margin-top: 10px;">
# <strong>Physical Meaning:</strong> Energy input as heat, per unit mass, per unit temperature rise, for a constant-pressure heating process
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Deriving the Physical Meaning</h3>
#
# <p style="color: #c9d1d9;">
# Consider heating a substance with a <strong>weighted piston</strong> (constant pressure):
# </p>
#
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; background: #0d1117; padding: 20px; border-radius: 8px; border: 1px solid #30363d; color: #c9d1d9; line-height: 1.2;">
#   Energy Balance:  δq = du + p·dv
#
#   At constant pressure:  δq = d(u + pv) = dh
#                               ↓
#                          δq = c<sub>p</sub>·dT
# </pre>
#
# <p style="color: #3fb950; font-weight: bold; margin-top: 15px;">
# Interpretation: c<sub>p</sub> tells you how much heat is needed to raise temperature by 1°C when pressure is constant!
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">⚡ c<sub>p</sub> vs c<sub>v</sub> - The Showdown!</h3>
#
# <table style="width:100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #0d1117;">
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Aspect</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">c<sub>v</sub></th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">c<sub>p</sub></th>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Constant</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Volume (v)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Pressure (p)</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Related to</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Internal Energy (u)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Enthalpy (h)</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Container</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Rigid (like a bomb)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Flexible (weighted piston)</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Magnitude</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Smaller (c<sub>v</sub> < c<sub>p</sub>)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Larger (c<sub>p</sub> > c<sub>v</sub>)</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Why?</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Heat ONLY goes to T rise</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Heat goes to T rise + expansion work</td>
# </tr>
# </table>
#
# <p style="color: #3fb950; font-weight: bold; margin-top: 15px;">
# 🎯 Key: c<sub>p</sub> is ALWAYS greater than c<sub>v</sub> because at constant pressure, some heat energy goes into doing expansion work!
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #f85149;">
# <strong style="color: #f85149;">🚨 SPECIAL CASE: Inside Vapor Dome</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# If you look at p-h chart inside the vapor-liquid dome:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>At constant p, T does NOT change (horizontal line in dome)</li>
# <li>But h DOES change (moving from f to g)</li>
# <li>Since c<sub>p</sub> = (∂h/∂T)<sub>p</sub>, and dT = 0 but dh ≠ 0...</li>
# </ul>
# <p style="color: #f85149; font-weight: bold; font-size: 16px; margin-top: 10px;">
# → c<sub>p</sub> is INFINITE in two-phase region! ♾️
# </p>
# <p style="color: #8b949e; font-style: italic;">
# This makes sense - you can add heat indefinitely without T rising during phase change!
# </p>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Trick: Specific Heats</h3>
# <p style="color: #c9d1d9;">
# <strong>"V for Volcano (contained), P for Party (expanding)"</strong>
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>c<sub>v</sub></strong> - Like a volcano in a rigid container, all energy goes to internal temperature rise 🌋</li>
# <li><strong>c<sub>p</sub></strong> - Like a party that expands, energy goes to both heating AND expansion 🎉</li>
# </ul>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# That's why c<sub>p</sub> > c<sub>v</sub> - expansion needs extra energy!
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #3fb950; border-radius: 8px;">
# <h2 style="color: #3fb950; margin:0;">🏆 4.7 Enthalpy - The Real MVP!</h2>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 DEFINITION: Enthalpy</strong>
#
# <p style="color: #c9d1d9; margin-top: 10px;">
# Enthalpy is defined as:
# </p>
#
# <p style="color: #3fb950; font-weight: bold; font-size: 20px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #3fb950;">
# H = U + pV
# </p>
#
# <p style="color: #c9d1d9; margin-top: 15px;">
# The specific enthalpy (per unit mass):
# </p>
#
# <p style="color: #3fb950; font-weight: bold; font-size: 20px; margin-top: 10px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #3fb950;">
# h = u + pv
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🤔 Why Add pV to U?</h3>
# <p style="color: #c9d1d9;">
# Both U and pV have units of <strong>ENERGY</strong>, so addition makes sense dimensionally.
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# But why do we care about this combination?
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">✅ THE BIG REASON</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Enthalpy appears <strong>NATURALLY</strong> in energy balances for <strong>open systems</strong> (control volumes)!
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Examples of open systems:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Turbines (steam flows in, does work, flows out)</li>
# <li>Compressors (air flows in, gets compressed, flows out)</li>
# <li>Heat exchangers (fluids flow through)</li>
# <li>Nozzles, diffusers, pipes, etc.</li>
# </ul>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px;">
# Most engineering devices are OPEN systems, not closed! That's why h is more useful than u!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">📊 Practical Consequence</h3>
# <p style="color: #c9d1d9;">
# Since h is more useful in practice:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Most thermodynamic <strong>tables</strong> display h (not u)</li>
# <li>Most thermodynamic <strong>charts</strong> show h (not u)</li>
# <li>If you need u, calculate it: <strong>u = h - pv</strong></li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Real-Life Analogy</h3>
# <p style="color: #c9d1d9;">
# Think of enthalpy as the <strong>"total package price"</strong> for moving energy:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>u</strong> = The product cost (internal energy)</li>
# <li><strong>pv</strong> = The shipping/flow work (energy to push fluid)</li>
# <li><strong>h = u + pv</strong> = Total cost to deliver!</li>
# </ul>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# When fluid flows, you pay for both the energy it carries AND the work to push it! 📦
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #a371f7; border-radius: 8px;">
# <h2 style="color: #a371f7; margin:0;">🧊 4.8 Incompressible Substance - The Easiest Case!</h2>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 CONCEPT: Incompressible Substance</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# An <strong>idealization</strong> where we assume:
# </p>
# <ol style="color: #c9d1d9; line-height: 1.8;">
# <li>Specific volume (density) is <strong>CONSTANT</strong></li>
# <li>Internal energy varies <strong>ONLY with temperature</strong></li>
# </ol>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">🎯 When to Use This Model?</h3>
# <p style="color: #c9d1d9;">
# This approximation works well for:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>Liquids</strong> (water, oil, etc.) - Very hard to compress</li>
# <li><strong>Solids</strong> (metals, etc.) - Even harder to compress</li>
# </ul>
# <p style="color: #f85149; font-weight: bold; margin-top: 10px;">
# ❌ Does NOT work for gases/vapors - they compress easily!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #a371f7;">
# <strong style="color: #a371f7;">🌟 THE TWO GOLDEN RULES</strong>
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 5px; margin-top: 15px;">
# <p style="color: #a371f7; font-weight: bold;">Rule 1: Constant Volume</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 10px;">
# v = constant
# </p>
# <p style="color: #8b949e; font-style: italic;">
# Doesn't change with pressure OR temperature
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 5px; margin-top: 15px;">
# <p style="color: #a371f7; font-weight: bold;">Rule 2: u depends only on T</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 10px;">
# u = u(T)
# </p>
# <p style="color: #8b949e; font-style: italic;">
# Pressure doesn't affect internal energy
# </p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Specific Heat for Incompressible</h3>
# <p style="color: #c9d1d9;">
# Since u = u(T) only:
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; margin-top: 10px;">
# c<sub>v</sub>(T) = du/dT
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Note: This is an <strong>ordinary derivative</strong> (not partial) because u depends only on T!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">⚡ What About Enthalpy?</h3>
# <p style="color: #c9d1d9;">
# Even though v is constant and u = u(T), enthalpy h varies with BOTH T and p!
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; margin-top: 10px;">
# h(T, p) = u(T) + p·v
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Because of the <strong>p·v</strong> term, h changes with pressure even though v doesn't!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">✅ AMAZING RESULT: c<sub>p</sub> = c<sub>v</sub> for Incompressible!</strong>
#
# <p style="color: #c9d1d9; margin-top: 10px;">
# Taking partial derivative of h = u(T) + pv with respect to T at constant p:
# </p>
#
# <p style="color: #c9d1d9; text-align: center; background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# (∂h/∂T)<sub>p</sub> = du/dT + p·(∂v/∂T)<sub>p</sub>
# </p>
#
# <p style="color: #c9d1d9; margin-top: 10px;">
# But for incompressible: (∂v/∂T)<sub>p</sub> = 0 (v is constant!)
# </p>
#
# <p style="color: #c9d1d9; text-align: center; background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# c<sub>p</sub> = du/dT = c<sub>v</sub>
# </p>
#
# <p style="color: #3fb950; font-weight: bold; font-size: 18px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #3fb950;">
# c<sub>p</sub> = c<sub>v</sub> = c(T)
# </p>
#
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# We just call it 'c' - one specific heat for all processes!
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #a371f7;">📐 Change in Properties for Incompressible</h3>
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 5px; margin-top: 15px;">
# <p style="color: #3fb950; font-weight: bold;">Change in Internal Energy:</p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; margin-top: 10px;">
# u₂ - u₁ = ∫(T₁ to T₂) c(T) dT
# </p>
# <p style="color: #8b949e; font-style: italic;">
# Only depends on temperature change!
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 15px; border-radius: 5px; margin-top: 15px;">
# <p style="color: #3fb950; font-weight: bold;">Change in Enthalpy:</p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; margin-top: 10px;">
# h₂ - h₁ = (u₂ - u₁) + v(p₂ - p₁)
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; margin-top: 5px;">
# h₂ - h₁ = ∫(T₁ to T₂) c(T) dT + v(p₂ - p₁)
# </p>
# <p style="color: #8b949e; font-style: italic;">
# Depends on BOTH temperature AND pressure change!
# </p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Trick: Incompressible</h3>
# <p style="color: #c9d1d9;">
# <strong>"Rock Solid, Won't Budge!"</strong>
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>v</strong> = Constant (volume doesn't budge)</li>
# <li><strong>u</strong> = u(T) only (only temperature matters for internal energy)</li>
# <li><strong>c<sub>p</sub> = c<sub>v</sub></strong> = Same! (No distinction needed)</li>
# <li><strong>β = 0, κ = 0</strong> (Won't expand with heat, won't compress with pressure)</li>
# </ul>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# Think of a stubborn rock that refuses to change size no matter what you do! 🪨
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 20px; border-left: 5px solid #a371f7; border-radius: 8px;">
# <h1 style="color: #a371f7; margin:0;">📝 EXAM CORNER - PART 2</h1>
# <p style="color: #8b949e; margin-top:5px;">Quick Revision for This Part!</p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">📊 Master Summary Table - Part 2</h3>
#
# <table style="width:100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #0d1117;">
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Concept</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Formula/Key Point</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Usage</th>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Superheated Vapor Tables</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Organized by pressure, then temperature</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Use p & T to find v, u, h, s</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Quality Formula</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">q = (1-x)·q<sub>f</sub> + x·q<sub>g</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Find properties in two-phase region</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Saturated Tables</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Temp table OR Pressure table</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Use whichever you're given</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Subcooled Liquid</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">v ≈ v<sub>f</sub>(T), u ≈ u<sub>f</sub>(T)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">When table data unavailable</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Isobaric Compressibility</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">β = (1/v)·(∂v/∂T)<sub>p</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">% volume increase per K at const. p</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Isothermal Compressibility</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">κ = -(1/v)·(∂v/∂p)<sub>T</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">% volume decrease per Pa at const. T</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">c<sub>v</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">c<sub>v</sub> = (∂u/∂T)<sub>v</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Specific heat at constant volume</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">c<sub>p</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">c<sub>p</sub> = (∂h/∂T)<sub>p</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Specific heat at constant pressure</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">c<sub>p</sub> vs c<sub>v</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">c<sub>p</sub> > c<sub>v</sub> (always)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Except incompressible: c<sub>p</sub> = c<sub>v</sub></td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Enthalpy</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">h = u + pv</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">More useful than u for open systems</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Incompressible</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">v = const, u = u(T), c<sub>p</sub> = c<sub>v</sub></td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Good for liquids & solids</td>
# </tr>
# </table>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Tricks - Part 2</h3>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">1. Quality Formula</p>
# <p style="color: #c9d1d9;">"<strong>Weighted Average Magic</strong>" - Like calculating semester grades!</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">2. Which Table?</p>
# <p style="color: #c9d1d9;">"<strong>Use What You're Given</strong>" - Given T → Temp table, Given p → Pressure table</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">3. Compressibilities</p>
# <p style="color: #c9d1d9;">"<strong>β expands, κ kompresses</strong>"</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">4. Specific Heats</p>
# <p style="color: #c9d1d9;">"<strong>V = Volcano contained, P = Party expanding</strong>" → c<sub>p</sub> > c<sub>v</sub></p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">5. Enthalpy</p>
# <p style="color: #c9d1d9;">"<strong>h = Total package price</strong>" (product + shipping)</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">6. Incompressible</p>
# <p style="color: #c9d1d9;">"<strong>Rock Solid, Won't Budge!</strong>" → Everything simple!</p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">⚡ One-Liners for 1-Minute Revision</h3>
#
# <ol style="color: #c9d1d9; line-height: 2.0;">
# <li><strong>Never use software as blackbox</strong> - Learn tables first!</li>
# <li><strong>Superheated tables</strong> organized by p, then T (p & T independent there)</li>
# <li><strong>Quality formula</strong>: q = (1-x)·q<sub>f</sub> + x·q<sub>g</sub> (weighted average)</li>
# <li><strong>Quality range</strong>: 0 ≤ x ≤ 1, only in two-phase region</li>
# <li><strong>Temp vs Pressure table</strong> - Same data, different organization</li>
# <li><strong>Subcooled liquid approximation</strong>: v ≈ v<sub>f</sub>(T), u ≈ u<sub>f</sub>(T)</li>
# <li><strong>Linear interpolation</strong> when exact values not in table</li>
# <li><strong>β (beta)</strong> = Isobaric compressibility = expansion with T at const p</li>
# <li><strong>κ (kappa)</strong> = Isothermal compressibility = compression with p at const T</li>
# <li><strong>c<sub>v</sub></strong> = Heat per degree at constant volume = (∂u/∂T)<sub>v</sub></li>
# <li><strong>c<sub>p</sub></strong> = Heat per degree at constant pressure = (∂h/∂T)<sub>p</sub></li>
# <li><strong>c<sub>p</sub> > c<sub>v</sub></strong> always (except incompressible where equal)</li>
# <li><strong>c<sub>p</sub> = ∞</strong> in two-phase region (T constant but h changes)</li>
# <li><strong>Enthalpy</strong> h = u + pv (more useful than u for open systems)</li>
# <li><strong>Most tables show h</strong> not u (calculate u = h - pv if needed)</li>
# <li><strong>Incompressible</strong>: v = const, u = u(T) only</li>
# <li><strong>For incompressible</strong>: β = 0, κ = 0, c<sub>p</sub> = c<sub>v</sub> = c(T)</li>
# <li><strong>Δu for incompressible</strong>: ∫c(T)dT (only T matters)</li>
# <li><strong>Δh for incompressible</strong>: ∫c(T)dT + v(p₂ - p₁) (T and p matter)</li>
# <li><strong>Liquids & solids</strong> well-modeled as incompressible</li>
# </ol>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #f85149;">🚨 Common Mistakes - Part 2</h3>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px; border-left: 3px solid #f85149;">
# <p style="color: #f85149; font-weight: bold;">❌ Mistake 1:</p>
# <p style="color: #c9d1d9;">Forgetting to interpolate when exact values not in table</p>
# <p style="color: #3fb950;">✅ Reality: Always interpolate linearly between adjacent values!</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px; border-left: 3px solid #f85149;">
# <p style="color: #f85149; font-weight: bold;">❌ Mistake 2:</p>
# <p style="color: #c9d1d9;">Using quality formula outside two-phase region</p>
# <p style="color: #3fb950;">✅ Reality: Quality ONLY defined between f and g!</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px; border-left: 3px solid #f85149;">
# <p style="color: #f85149; font-weight: bold;">❌ Mistake 3:</p>
# <p style="color: #c9d1d9;">Thinking c<sub>p</sub> = c<sub>v</sub> for gases</p>
# <p style="color: #3fb950;">✅ Reality: c<sub>p</sub> = c<sub>v</sub> ONLY for incompressible substances!</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px; border-left: 3px solid #f85149;">
# <p style="color: #f85149; font-weight: bold;">❌ Mistake 4:</p>
# <p style="color: #c9d1d9;">Using wrong table (temperature when you have pressure)</p>
# <p style="color: #3fb950;">✅ Reality: Use the table that matches your given property!</p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💎 Pro Tips - Part 2</h3>
#
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>🎯 Practice reading tables - it's a skill that improves with use!</li>
# <li>🎯 Quality problems: Always write q = (1-x)·q<sub>f</sub> + x·q<sub>g</sub> first</li>
# <li>🎯 For subcooled liquid: Check if approximation is acceptable before using</li>
# <li>🎯 Enthalpy is your friend in open systems - memorize h = u + pv</li>
# <li>🎯 c<sub>p</sub> > c<sub>v</sub> because expansion needs extra energy</li>
# <li>🎯 For water/oil/solids: Use incompressible model to simplify!</li>
# <li>🎯 Units matter! Check if table uses kJ or J, kg or g</li>
# <li>🎯 When interpolating, be systematic - write down known values first</li>
# </ul>
#
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; text-align: center;">
# <h2 style="color: #ffffff; margin: 0;">🎉 Part 2 Complete!</h2>
# <p style="color: #ffffff; margin-top: 10px; font-size: 18px;">
# Awesome progress, bro! You're mastering this! 💪
# </p>
# <p style="color: #ffffff; margin-top: 10px;">
# You now know:<br>
# ✅ How to read Steam Tables like a pro<br>
# ✅ Quality formula for mixtures<br>
# ✅ Derivative Properties (β, κ, c<sub>v</sub>, c<sub>p</sub>)<br>
# ✅ Enthalpy and why it's the MVP<br>
# ✅ Incompressible substances<br>
# </p>
# <p style="color: #ffeb3b; margin-top: 15px; font-size: 20px; font-weight: bold;">
# Ready for Part 3? Just say "NEXT"! 🚀
# </p>
# </div>
