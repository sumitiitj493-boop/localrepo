# %% [markdown]
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 20px; border-left: 5px solid #d29922; border-radius: 8px;">
# <h1 style="color: #c9d1d9; margin:0;">⚛️ Properties of Pure Substance - PART 3</h1>
# <p style="color: #8b949e; margin-top:5px;">Chapter 4 | The Ideal Gas - Where Molecules Play Free! 🎈</p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h2 style="color: #58a6ff; margin-top:0;">📚 In This Part</h2>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>What the heck is an <strong>Ideal Gas</strong>? 🎈</li>
# <li>The legendary <strong>Ideal Gas Equation</strong> (PV = nRT)</li>
# <li>Why <strong>u</strong> and <strong>h</strong> depend ONLY on temperature for ideal gas! 🌡️</li>
# <li><strong>Microscopic Analysis</strong> - From molecules to pressure! ⚛️</li>
# <li>Specific heats for <strong>Monatomic Gases</strong></li>
# <li>The <strong>Equipartition Model</strong> - Energy sharing made simple!</li>
# <li><strong>Diatomic Molecules</strong> - When molecules get complex! 🤸</li>
# </ul>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #58a6ff; border-radius: 8px;">
# <h2 style="color: #58a6ff; margin:0;">🎈 4.9 Ideal Gas - The Perfect Model</h2>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 DEFINITION: Ideal Gas (Perfect Gas)</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# An <strong>ideal gas</strong> is any substance that obeys the equation of state:
# </p>
# <p style="color: #3fb950; font-weight: bold; font-size: 20px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #3fb950;">
# p = ρRT
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Or equivalently (specific volume form):
# </p>
# <p style="color: #3fb950; font-weight: bold; font-size: 20px; margin-top: 10px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #3fb950;">
# pv = RT
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 What is R?</h3>
# <p style="color: #c9d1d9;">
# R is the <strong>specific gas constant</strong> for that particular gas.
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# R = R̂ / M̂
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Where:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>R̂</strong> = Universal gas constant = 8.3143 J/(mol·K) (SAME for all gases!)</li>
# <li><strong>M̂</strong> = Molar mass (mass per mole) of the substance (DIFFERENT for each gas)</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">📐 Different Forms of Ideal Gas Equation</h3>
#
# <table style="width:100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #0d1117;">
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Form</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Equation</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">When to Use</th>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Intensive (density)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">p = ρRT</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">When density ρ is given</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Intensive (specific volume)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">pv = RT</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">When specific volume v is given</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Extensive (mass)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">pV̄ = MRT</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">When total mass M is given</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Extensive (moles)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">pV̄ = NR̂T</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">When number of moles N is given</td>
# </tr>
# </table>
#
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# V̄ = Total volume, M = Total mass, N = Number of moles
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Real-Life Analogy</h3>
# <p style="color: #c9d1d9;">
# Think of an ideal gas like a <strong>dance floor with very few people</strong>:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Dancers (molecules) are <strong>far apart</strong> - plenty of space to move 💃</li>
# <li>They barely interact with each other (no intermolecular forces)</li>
# <li>They just bounce off walls (pressure from collisions)</li>
# <li>More energy (temperature) → Faster dancing!</li>
# </ul>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# A crowded nightclub? That's like a liquid - molecules interact strongly! 🕺
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #d29922;">
# <strong style="color: #d29922;">⚠️ When is Ideal Gas Model Valid?</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Look at property charts to check!
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>High specific volume</strong> (low density) - molecules far apart</li>
# <li><strong>Low pressure</strong> - less crowding</li>
# <li><strong>Far from vapor dome</strong> - well into gas region</li>
# <li><strong>High temperature</strong> - molecules moving fast, interactions negligible</li>
# </ul>
# <p style="color: #3fb950; font-weight: bold; margin-top: 15px; font-size: 16px;">
# 🎯 Golden Rule: In the limit ρ → 0, ALL substances behave like ideal gas!
# </p>
# <p style="color: #8b949e; font-style: italic;">
# At very low density, even water vapor acts ideal!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">📊 Visual Check on T-v Diagram</h3>
# <p style="color: #c9d1d9;">
# On T-v diagram (like for methane):
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Isobars (constant p lines) become <strong>nearly straight</strong> in gas region</li>
# <li>Doubling pressure → Halves volume (at same T)</li>
# <li>This indicates <strong>pv = constant</strong> at fixed T → Ideal gas behavior!</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Trick: Ideal Gas Equation</h3>
# <p style="color: #c9d1d9;">
# <strong>"Please Verify Results Thoroughly"</strong>
# </p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 10px;">
# P V = R T
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Or the famous version everyone knows:
# </p>
# <p style="color: #3fb950; font-size: 18px; text-align: center;">
# PV = nRT (with n = number of moles, R = R̂)
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #3fb950; border-radius: 8px;">
# <h2 style="color: #3fb950; margin:0;">🌡️ 4.9.1 Internal Energy of Ideal Gas</h2>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 THE BIG INSIGHT</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Internal energy of ideal gas consists of:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>Translational energy</strong> - molecules moving in space 🏃</li>
# <li><strong>Rotational energy</strong> - molecules spinning 🌀</li>
# <li><strong>Vibrational energy</strong> - atoms vibrating within molecule 📳</li>
# </ul>
# <p style="color: #d29922; font-weight: bold; margin-top: 15px; font-size: 16px;">
# ⚡ Key Point: NO significant energy from intermolecular forces!
# </p>
# <p style="color: #c9d1d9;">
# Why? Because molecules are <strong>very far apart</strong> on average!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #a371f7;">
# <strong style="color: #a371f7;">🌟 THE GOLDEN RULE FOR IDEAL GAS</strong>
# <p style="color: #a371f7; font-weight: bold; font-size: 20px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #a371f7;">
# u = u(T)
# </p>
# <p style="color: #c9d1d9; margin-top: 10px; text-align: center; font-size: 16px;">
# <strong>Internal energy depends ONLY on temperature!</strong>
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# It does NOT depend on:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>❌ Pressure</li>
# <li>❌ Volume</li>
# <li>❌ Density</li>
# <li>✅ ONLY Temperature!</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Why Only Temperature?</h3>
# <p style="color: #c9d1d9;">
# Temperature is a measure of <strong>average molecular kinetic energy</strong>.
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Since ideal gas molecules don't interact:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>No potential energy from intermolecular forces</li>
# <li>Only kinetic energy matters</li>
# <li>Kinetic energy ∝ Temperature</li>
# <li>Therefore: u = u(T) only!</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">📊 Visual Verification on v-u Diagram</h3>
# <p style="color: #c9d1d9;">
# On v-u diagram of water (at low pressures, outside vapor dome):
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>Temperature lines and internal energy lines coincide</strong></li>
# <li>This confirms: u is independent of density (or volume)</li>
# <li>u only changes with T!</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Real-Life Analogy</h3>
# <p style="color: #c9d1d9;">
# Think of internal energy like <strong>your phone's battery charge</strong>:
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# For an ideal gas:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Battery charge (u) depends ONLY on how much you've charged it (T)</li>
# <li>Doesn't matter if phone is in your pocket or on table (volume/pressure irrelevant)</li>
# <li>Doesn't matter if you're using it or not (density irrelevant)</li>
# </ul>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# Same temperature → Same internal energy, no matter what the pressure or volume! 📱
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #3fb950; border-radius: 8px;">
# <h2 style="color: #3fb950; margin:0;">🎯 4.9.2 Enthalpy for Ideal Gas</h2>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🧮 The Derivation</h3>
# <p style="color: #c9d1d9;">
# We know:
# </p>
# <ol style="color: #c9d1d9; line-height: 1.8;">
# <li>h = u + pv (definition of enthalpy)</li>
# <li>u = u(T) (just proved above)</li>
# <li>pv = RT (ideal gas equation)</li>
# </ol>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Substituting:
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #161b22; padding: 10px; border-radius: 5px; margin-top: 10px;">
# h = u(T) + RT
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Since both u(T) and RT depend only on T:
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #a371f7;">
# <strong style="color: #a371f7;">🌟 THE SECOND GOLDEN RULE</strong>
# <p style="color: #a371f7; font-weight: bold; font-size: 20px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #a371f7;">
# h = h(T)
# </p>
# <p style="color: #c9d1d9; margin-top: 10px; text-align: center; font-size: 16px;">
# <strong>Enthalpy also depends ONLY on temperature!</strong>
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">📊 Visual Verification on p-h Diagram</h3>
# <p style="color: #c9d1d9;">
# On p-h diagram of water (at high volumes in gas region):
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>Enthalpy lines (h) and Temperature lines (T) coincide</strong></li>
# <li>This confirms ideal gas behavior in that region</li>
# <li>h changes only when T changes!</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Trick: Ideal Gas Properties</h3>
# <p style="color: #c9d1d9;">
# <strong>"Temperature Takes Total Control"</strong>
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# For ideal gas:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>u = u(T) - Temperature controls internal energy</li>
# <li>h = h(T) - Temperature controls enthalpy</li>
# <li>Both independent of p and v!</li>
# </ul>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# Temperature is the ONLY boss for ideal gas energy properties! 👑
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #d29922; border-radius: 8px;">
# <h2 style="color: #d29922; margin:0;">🔥 4.9.3 Specific Heats for Ideal Gas</h2>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🎯 Starting Point</h3>
# <p style="color: #c9d1d9;">
# Since u and h depend only on temperature:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>u = u(T) → c<sub>v</sub> must also depend only on T</li>
# <li>h = h(T) → c<sub>p</sub> must also depend only on T</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">✅ c<sub>v</sub> for Ideal Gas</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# From definition:
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# c<sub>v</sub> = (∂u/∂T)<sub>v</sub>
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# But since u = u(T) only (doesn't depend on v):
# </p>
# <p style="color: #3fb950; font-weight: bold; font-size: 18px; margin-top: 10px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #3fb950;">
# c<sub>v</sub> = du/dT
# </p>
# <p style="color: #8b949e; font-style: italic; margin-top: 5px;">
# Regular derivative (not partial) because u depends only on T!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">✅ c<sub>p</sub> for Ideal Gas</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# From definition:
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# c<sub>p</sub> = (∂h/∂T)<sub>p</sub> = dh/dT
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Since h = u + pv = u + RT:
# </p>
# <p style="color: #c9d1d9; text-align: center; background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# dh/dT = du/dT + R
# </p>
# <p style="color: #3fb950; font-weight: bold; font-size: 18px; margin-top: 10px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #3fb950;">
# c<sub>p</sub> = c<sub>v</sub> + R
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #a371f7;">
# <strong style="color: #a371f7;">🌟 THE FAMOUS RELATION</strong>
# <p style="color: #a371f7; font-weight: bold; font-size: 22px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #a371f7;">
# c<sub>p</sub> = c<sub>v</sub> + R
# </p>
# <p style="color: #c9d1d9; margin-top: 10px; text-align: center;">
# This is <strong>THE</strong> most important relation for ideal gases!
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# It tells us:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>c<sub>p</sub> is always greater than c<sub>v</sub> by exactly R</li>
# <li>The difference is the gas constant!</li>
# <li>If you know one, you know the other!</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Why c<sub>p</sub> > c<sub>v</sub>?</h3>
# <p style="color: #c9d1d9;">
# Remember from Part 2:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>At <strong>constant volume</strong>: All heat goes to increasing internal energy (temperature)</li>
# <li>At <strong>constant pressure</strong>: Heat goes to BOTH temperature rise AND expansion work (pΔv)</li>
# <li>Therefore: c<sub>p</sub> > c<sub>v</sub></li>
# </ul>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px;">
# For ideal gas, the difference is exactly R!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">📐 Temperature Dependence of c<sub>v</sub> and c<sub>p</sub></h3>
#
# <table style="width:100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #0d1117;">
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Gas Type</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Temperature Dependence</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Why?</th>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Monatomic<br>(He, Ar, Ne)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">CONSTANT<br>(c<sub>v</sub>, c<sub>p</sub> don't change with T)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Only translational energy, which is linearly proportional to T</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Polyatomic<br>(O₂, N₂, CO₂)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">INCREASE with T<br>(nonlinear relationship)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Rotation and vibration energy increase nonlinearly with T</td>
# </tr>
# </table>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #d29922;">
# <strong style="color: #d29922;">⚠️ PRACTICAL APPROXIMATION</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Although c<sub>v</sub> and c<sub>p</sub> vary with temperature for polyatomic gases:
# </p>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px; font-size: 16px;">
# Over LIMITED temperature ranges, we often assume c<sub>v</sub> and c<sub>p</sub> are CONSTANT!
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Why?
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Makes analytical solutions possible</li>
# <li>Simplifies calculations enormously</li>
# <li>Gives reasonably accurate results for small ΔT</li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">✈️ SPECIAL CASE: Air</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Although air is a <strong>mixture</strong> of gases (N₂ ~78%, O₂ ~21%, others ~1%):
# </p>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px; font-size: 16px;">
# 🎯 Air can usually be treated as an IDEAL GAS!
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Properties of air as ideal gas:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>R<sub>air</sub> ≈ 0.287 kJ/(kg·K)</li>
# <li>c<sub>p</sub> ≈ 1.005 kJ/(kg·K)</li>
# <li>c<sub>v</sub> ≈ 0.718 kJ/(kg·K)</li>
# <li>γ = c<sub>p</sub>/c<sub>v</sub> ≈ 1.4</li>
# </ul>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# These values are super important - memorize them! They're used everywhere in engineering! ✈️
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Trick: Specific Heats Relation</h3>
# <p style="color: #c9d1d9;">
# <strong>"Constant Pressure Volunteers to do extra work (R)"</strong>
# </p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 10px;">
# c<sub>p</sub> = c<sub>v</sub> + R
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# c<sub>p</sub> volunteers to do extra work (expansion), so it's bigger by R!
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #58a6ff; border-radius: 8px;">
# <h2 style="color: #58a6ff; margin:0;">⚛️ 4.9.4 Pressure in Ideal Gas - Microscopic View!</h2>
# <p style="color: #8b949e; margin-top:5px;">Time to go DEEP into the molecular world! 🔬</p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🎯 The Big Question</h3>
# <p style="color: #c9d1d9; font-size: 16px;">
# What IS pressure, really, at the molecular level?
# </p>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px; font-size: 16px;">
# Answer: Pressure = Rate of momentum transfer per unit area from molecular collisions!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🧮 The Setup</h3>
# <p style="color: #c9d1d9;">
# Imagine:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Molecules bouncing around inside a container</li>
# <li>They hit the walls and bounce back</li>
# <li>Each collision transfers momentum to the wall</li>
# <li>Billions of collisions per second → Pressure!</li>
# </ul>
# </div>

# %% [markdown]
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; background: #0d1117; padding: 20px; border-radius: 8px; border: 1px solid #30363d; color: #c9d1d9; line-height: 1.2;">
#     Molecular Collisions with Wall
#
#     ┌────────────────────────────────┐
#     │                                │
#     │    *  -->  |                   │
#     │            |  Wall             │
#     │    <--  *  |                   │
#     │            |                   │
#     │  *  -->    |                   │
#     │            |                   │
#     │       <--* |                   │
#     │            |                   │
#     └────────────────────────────────┘
#
#     Before collision: velocity = +Vx (towards wall)
#     After collision:  velocity = -Vx (away from wall)
#     Momentum change:  Δp = m(-Vx - Vx) = -2mVx
# </pre>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Step-by-Step Derivation</h3>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Step 1: How many molecules hit the wall?</p>
# <p style="color: #c9d1d9;">
# Consider molecules with x-velocity component = V<sub>x</sub><br>
# In time dt, those within distance V<sub>x</sub>·dt can reach the wall<br>
# Only HALF are moving towards wall (other half moving away)
# </p>
# <p style="color: #3fb950; text-align: center; margin-top: 5px;">
# Number hitting unit area = (1/2) × n' × V<sub>x</sub> dt
# </p>
# <p style="color: #8b949e; font-style: italic;">
# n' = number of molecules per unit volume with this particular V<sub>x</sub>
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Step 2: Momentum change per molecule</p>
# <p style="color: #c9d1d9;">
# Before collision: p<sub>x</sub> = m·V<sub>x</sub> (towards wall)<br>
# After collision: p<sub>x</sub> = m·(-V<sub>x</sub>) (away from wall)<br>
# Change in molecular momentum: Δp = m(-V<sub>x</sub>) - m(V<sub>x</sub>) = -2mV<sub>x</sub>
# </p>
# <p style="color: #c9d1d9; margin-top: 5px;">
# By Newton's 3rd law, wall gains momentum: +2mV<sub>x</sub>
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Step 3: Total momentum transfer</p>
# <p style="color: #c9d1d9;">
# Total momentum to wall per unit area in time dt:
# </p>
# <p style="color: #3fb950; text-align: center; margin-top: 5px;">
# (1/2)·n'·V<sub>x</sub>·dt × 2m·V<sub>x</sub> = m·n'·V<sub>x</sub>²·dt
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Step 4: Sum over all speeds</p>
# <p style="color: #c9d1d9;">
# Rate of momentum transfer = Momentum/(unit area × time) = Pressure!
# </p>
# <p style="color: #3fb950; text-align: center; margin-top: 5px;">
# p = m·Σ(n'·V<sub>x</sub>²) = m·n·⟨V<sub>x</sub>²⟩
# </p>
# <p style="color: #8b949e; font-style: italic;">
# n = total molecules per unit volume, ⟨V<sub>x</sub>²⟩ = mean-square velocity in x-direction
# </p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🎯 Connecting to 3D Motion</h3>
# <p style="color: #c9d1d9;">
# Total mean-square velocity:
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# ⟨V²⟩ = ⟨V<sub>x</sub>²⟩ + ⟨V<sub>y</sub>²⟩ + ⟨V<sub>z</sub>²⟩
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Since molecular motion is <strong>isotropic</strong> (no preferred direction):
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# ⟨V<sub>x</sub>²⟩ = ⟨V<sub>y</sub>²⟩ = ⟨V<sub>z</sub>²⟩ = ⟨V²⟩/3
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #a371f7;">
# <strong style="color: #a371f7;">🌟 FINAL RESULT: Pressure Formula</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Substituting ⟨V<sub>x</sub>²⟩ = ⟨V²⟩/3:
# </p>
# <p style="color: #a371f7; font-weight: bold; font-size: 20px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #a371f7;">
# p = (1/3)·m·n·⟨V²⟩
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Since ρ = m·n (mass per unit volume):
# </p>
# <p style="color: #a371f7; font-weight: bold; font-size: 20px; margin-top: 10px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #a371f7;">
# p = (1/3)·ρ·⟨V²⟩
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">✅ CONNECTING TO TEMPERATURE</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# We know from ideal gas equation: p = ρRT
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Comparing with p = (1/3)·ρ·⟨V²⟩:
# </p>
# <p style="color: #3fb950; font-weight: bold; font-size: 20px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #3fb950;">
# RT = (1/3)·⟨V²⟩
# </p>
# <p style="color: #d29922; font-weight: bold; margin-top: 15px; font-size: 16px; text-align: center;">
# 🎯 Temperature is a measure of mean-square molecular velocity!
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Higher temperature → Faster moving molecules! 🏃‍♂️💨
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Real-Life Analogy</h3>
# <p style="color: #c9d1d9;">
# Pressure is like <strong>raindrops hitting your umbrella</strong>! ☔
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Each raindrop = molecule</li>
# <li>Hitting umbrella = collision with wall</li>
# <li>Force you feel = sum of all momentum transfers</li>
# <li>Heavier rain (more molecules) → More force (higher pressure)</li>
# <li>Faster raindrops (higher T) → More force (higher pressure)</li>
# </ul>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #3fb950; border-radius: 8px;">
# <h2 style="color: #3fb950; margin:0;">🎯 4.9.5 Monatomic Ideal Gas - The Simplest Case!</h2>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🎈 What's a Monatomic Gas?</h3>
# <p style="color: #c9d1d9;">
# A gas made of <strong>single atoms</strong> (not molecules).
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Examples:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Helium (He)</li>
# <li>Argon (Ar)</li>
# <li>Neon (Ne)</li>
# <li>All noble gases!</li>
# </ul>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px;">
# Key Feature: Internal energy is ENTIRELY from translational kinetic energy!
# </p>
# <p style="color: #8b949e; font-style: italic;">
# No rotation (atom is like a point), no vibration (single atom can't vibrate!)
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Internal Energy of Monatomic Gas</h3>
# <p style="color: #c9d1d9;">
# Kinetic energy per unit mass:
# </p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# u = (1/2)·⟨V²⟩
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Using RT = (1/3)·⟨V²⟩, so ⟨V²⟩ = 3RT:
# </p>
# <p style="color: #3fb950; font-weight: bold; font-size: 20px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #3fb950;">
# u = (3/2)·R·T
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Enthalpy of Monatomic Gas</h3>
# <p style="color: #c9d1d9;">
# Using h = u + pv = u + RT:
# </p>
# <p style="color: #c9d1d9; text-align: center; background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# h = (3/2)RT + RT
# </p>
# <p style="color: #3fb950; font-weight: bold; font-size: 20px; margin-top: 10px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #3fb950;">
# h = (5/2)·R·T
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #a371f7;">
# <strong style="color: #a371f7;">🌟 SPECIFIC HEATS FOR MONATOMIC GAS</strong>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">c<sub>v</sub>:</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 5px;">
# c<sub>v</sub> = du/dT = (3/2)·R
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">c<sub>p</sub>:</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 5px;">
# c<sub>p</sub> = dh/dT = (5/2)·R
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Specific Heat Ratio γ:</p>
# <p style="color: #a371f7; font-size: 20px; text-align: center; margin-top: 5px; font-weight: bold;">
# γ = c<sub>p</sub>/c<sub>v</sub> = (5/2)R / (3/2)R = 5/3 ≈ 1.667
# </p>
# </div>
#
# <p style="color: #d29922; font-weight: bold; margin-top: 15px; font-size: 16px;">
# 🎯 These values are CONSTANTS for all monatomic gases!
# </p>
#
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Key Insight</h3>
# <p style="color: #c9d1d9;">
# For monatomic gases:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Internal energy per mole is <strong>SAME</strong> for all (depends only on R and T)</li>
# <li>Enthalpy per mole is <strong>SAME</strong> for all</li>
# <li>c<sub>v</sub>, c<sub>p</sub>, γ are <strong>universal constants</strong></li>
# <li>Helium, Argon, Neon all have γ = 5/3!</li>
# </ul>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #d29922; border-radius: 8px;">
# <h2 style="color: #d29922; margin:0;">⚖️ 4.9.6 Equipartition Model - Energy Sharing!</h2>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">📚 THE EQUIPARTITION PRINCIPLE</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# A simple but powerful rule:
# </p>
# <p style="color: #3fb950; font-weight: bold; font-size: 16px; margin-top: 10px; text-align: center;">
# Each available mode of motion (degree of freedom) contributes THE SAME amount to the system's energy!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🎯 Proof from Monatomic Gas</h3>
# <p style="color: #c9d1d9;">
# Monatomic molecule has <strong>3 degrees of freedom</strong>:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Translation in x-direction</li>
# <li>Translation in y-direction</li>
# <li>Translation in z-direction</li>
# </ul>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Total internal energy: u = (3/2)RT
# </p>
# <p style="color: #3fb950; font-weight: bold; font-size: 18px; margin-top: 10px; text-align: center; background-color: #161b22; padding: 10px; border-radius: 5px;">
# Energy per degree of freedom = (1/2)RT
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #a371f7;">
# <strong style="color: #a371f7;">🌟 THE GOLDEN RULE</strong>
# <p style="color: #a371f7; font-weight: bold; font-size: 20px; margin-top: 15px; text-align: center; background-color: #0d1117; padding: 15px; border-radius: 5px; border: 2px solid #a371f7;">
# u = (f/2)·R·T
# </p>
# <p style="color: #c9d1d9; margin-top: 10px; text-align: center;">
# where f = number of degrees of freedom
# </p>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px;">
# This is THE equipartition model!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💡 Real-Life Analogy</h3>
# <p style="color: #c9d1d9;">
# Think of energy distribution like <strong>dividing pizza among friends</strong>! 🍕
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>Total pizza (energy) = (f/2)RT</li>
# <li>Number of friends = f (degrees of freedom)</li>
# <li>Each friend gets equal share = (1/2)RT</li>
# </ul>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# Fair distribution - every degree of freedom gets equal energy! ⚖️
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 15px; border-left: 5px solid #58a6ff; border-radius: 8px;">
# <h2 style="color: #58a6ff; margin:0;">🤸 4.9.7 Diatomic Molecules - Getting Complex!</h2>
# </div>

# %% [markdown]
# <div style="background-color: #0d1117; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🧬 What's a Diatomic Molecule?</h3>
# <p style="color: #c9d1d9;">
# A molecule made of <strong>TWO atoms</strong> bonded together.
# </p>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Examples:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>O₂ (Oxygen)</li>
# <li>N₂ (Nitrogen)</li>
# <li>H₂ (Hydrogen)</li>
# <li>Most gases in air are diatomic!</li>
# </ul>
# </div>

# %% [markdown]
# <pre style="white-space: pre; font-family: monospace; overflow-x: auto; background: #0d1117; padding: 20px; border-radius: 8px; border: 1px solid #30363d; color: #c9d1d9; line-height: 1.2;">
#     Diatomic Molecule - Degrees of Freedom
#
#          O----O  (like a dumbbell)
#
#     TRANSLATIONAL (3 modes):
#     - Move in x direction  -->
#     - Move in y direction  ^
#     - Move in z direction  (out of page)
#
#     ROTATIONAL (2 modes):
#          |           (rotation about axis
#       O--+--O         perpendicular to bond)
#          |
#
#       ___O___        (rotation about another
#          |            perpendicular axis)
#          O
#
#     (Rotation about bond axis negligible -
#      very small moment of inertia)
#
#     VIBRATIONAL (can have, but not always active):
#       O<-->O  (accordion mode)
# </pre>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Case 1: Rigid Diatomic (No Vibration)</h3>
# <p style="color: #c9d1d9;">
# At low to moderate temperatures, molecule acts <strong>rigid</strong> (no vibration):
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>3 translational modes</li>
# <li>2 rotational modes</li>
# <li><strong>Total: f = 5 degrees of freedom</strong></li>
# </ul>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">✅ PROPERTIES - Rigid Diatomic</strong>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Internal Energy:</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 5px;">
# u = (5/2)·R·T
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Enthalpy:</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 5px;">
# h = u + RT = (7/2)·R·T
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Specific Heats:</p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; margin-top: 5px;">
# c<sub>v</sub> = (5/2)·R,  c<sub>p</sub> = (7/2)·R
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Specific Heat Ratio:</p>
# <p style="color: #a371f7; font-size: 20px; text-align: center; margin-top: 5px; font-weight: bold;">
# γ = 7/5 = 1.4
# </p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #58a6ff;">
# <strong style="color: #58a6ff;">✈️ VALIDATION: Air!</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Low-density air has been experimentally found to have:
# </p>
# <p style="color: #3fb950; font-weight: bold; font-size: 18px; text-align: center; margin-top: 10px;">
# γ<sub>air</sub> ≈ 1.4
# </p>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px;">
# 🎯 Perfect match with rigid diatomic model!
# </p>
# <p style="color: #c9d1d9;">
# This validates the equipartition model for air (which is mostly N₂ and O₂).
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">🔥 Case 2: Vibrating Diatomic (High Temperature)</h3>
# <p style="color: #c9d1d9;">
# As temperature increases, vibrational mode becomes <strong>excited</strong>:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>3 translational modes</li>
# <li>2 rotational modes</li>
# <li>1 vibrational kinetic energy mode</li>
# <li>1 vibrational potential energy mode</li>
# <li><strong>Total: f = 7 degrees of freedom</strong></li>
# </ul>
# <p style="color: #8b949e; font-style: italic; margin-top: 10px;">
# Vibration adds TWO modes - one for KE (atoms moving), one for PE (spring-like potential)!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #3fb950;">
# <strong style="color: #3fb950;">✅ PROPERTIES - Vibrating Diatomic</strong>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Internal Energy:</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 5px;">
# u = (7/2)·R·T
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Enthalpy:</p>
# <p style="color: #3fb950; font-size: 18px; text-align: center; margin-top: 5px;">
# h = u + RT = (9/2)·R·T
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Specific Heats:</p>
# <p style="color: #3fb950; font-size: 16px; text-align: center; margin-top: 5px;">
# c<sub>v</sub> = (7/2)·R,  c<sub>p</sub> = (9/2)·R
# </p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">Specific Heat Ratio:</p>
# <p style="color: #a371f7; font-size: 20px; text-align: center; margin-top: 5px; font-weight: bold;">
# γ = 9/7 ≈ 1.286
# </p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d; border-left: 5px solid #d29922;">
# <strong style="color: #d29922;">⚠️ TEMPERATURE EFFECT</strong>
# <p style="color: #c9d1d9; margin-top: 10px;">
# For air:
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>At <strong>room temperature</strong>: γ ≈ 1.4 (rigid model, f = 5)</li>
# <li>As <strong>T increases</strong>: γ drops below 1.4 (vibration starts)</li>
# <li>At <strong>very high T</strong>: γ → 9/7 ≈ 1.286 (fully vibrating, f = 7)</li>
# </ul>
# <p style="color: #3fb950; font-weight: bold; margin-top: 10px;">
# This explains why specific heats increase with temperature for diatomic gases!
# </p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">📊 Summary Table: Degrees of Freedom</h3>
#
# <table style="width:100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #0d1117;">
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Gas Type</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">f</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">u</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">c<sub>v</sub></th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">c<sub>p</sub></th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">γ</th>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Monatomic</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">3</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">(3/2)RT</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">(3/2)R</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">(5/2)R</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">5/3 = 1.667</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Diatomic (rigid)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">5</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">(5/2)RT</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">(5/2)R</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">(7/2)R</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">7/5 = 1.4</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Diatomic (vibrating)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">7</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">(7/2)RT</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">(7/2)R</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">(9/2)R</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">9/7 = 1.286</td>
# </tr>
# </table>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Trick: γ Values</h3>
# <p style="color: #c9d1d9;">
# <strong>"3-5-7 Rule"</strong>
# </p>
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li><strong>Monatomic</strong>: f = 3 → γ = 5/3</li>
# <li><strong>Diatomic (rigid)</strong>: f = 5 → γ = 7/5</li>
# <li><strong>Diatomic (vibrating)</strong>: f = 7 → γ = 9/7</li>
# </ul>
# <p style="color: #c9d1d9; margin-top: 10px;">
# Pattern: γ = (f + 2)/f
# </p>
# <p style="color: #8b949e; font-style: italic;">
# More degrees of freedom → Smaller γ (energy spread over more modes)!
# </p>
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(to right, #161b22, #0d1117); padding: 20px; border-left: 5px solid #a371f7; border-radius: 8px;">
# <h1 style="color: #a371f7; margin:0;">📝 EXAM CORNER - PART 3</h1>
# <p style="color: #8b949e; margin-top:5px;">Master Revision for Ideal Gas!</p>
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">📊 Master Summary Table - Part 3</h3>
#
# <table style="width:100%; border-collapse: collapse; margin-top: 10px;">
# <tr style="background-color: #0d1117;">
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Concept</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Formula/Key Point</th>
# <th style="padding: 10px; border: 1px solid #30363d; color: #58a6ff;">Notes</th>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Ideal Gas Equation</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">pv = RT or p = ρRT</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">R = R̂/M̂, R̂ = 8.3143 J/(mol·K)</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">When Valid?</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Low density, high volume, far from vapor dome</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">ρ → 0: ALL substances ideal</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Internal Energy</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">u = u(T) only</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Independent of p, v</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Enthalpy</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">h = h(T) only</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">h = u + RT</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Specific Heats</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">c<sub>v</sub> = du/dT, c<sub>p</sub> = dh/dT</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Regular derivatives (not partial)</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">c<sub>p</sub> - c<sub>v</sub> Relation</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">c<sub>p</sub> = c<sub>v</sub> + R</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">THE most important relation!</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Pressure (microscopic)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">p = (1/3)ρ⟨V²⟩</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">From molecular collisions</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Temperature Meaning</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">RT = (1/3)⟨V²⟩</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Measure of molecular speed²</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Equipartition</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Energy per mode = (1/2)RT</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">u = (f/2)RT, f = # of modes</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Monatomic</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">f = 3, γ = 5/3</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">He, Ar, Ne</td>
# </tr>
# <tr>
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Diatomic (rigid)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">f = 5, γ = 7/5 = 1.4</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">Air, N₂, O₂ (room temp)</td>
# </tr>
# <tr style="background-color: #0d1117;">
# <td style="padding: 10px; border: 1px solid #30363d; color: #3fb950; font-weight: bold;">Diatomic (vibrating)</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">f = 7, γ = 9/7</td>
# <td style="padding: 10px; border: 1px solid #30363d; color: #c9d1d9;">High temperature</td>
# </tr>
# </table>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px dashed #a371f7;">
# <h3 style="color: #a371f7; margin-top:0;">🧠 Memory Tricks - Part 3</h3>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">1. Ideal Gas Equation</p>
# <p style="color: #c9d1d9;">"<strong>Please Verify Results Thoroughly</strong>" → PV = RT</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">2. Temperature Control</p>
# <p style="color: #c9d1d9;">"<strong>Temperature Takes Total Control</strong>" → u = u(T), h = h(T)</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">3. Specific Heats</p>
# <p style="color: #c9d1d9;">"<strong>CP Volunteers to do extra work R</strong>" → c<sub>p</sub> = c<sub>v</sub> + R</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">4. Equipartition</p>
# <p style="color: #c9d1d9;">"<strong>Pizza divided equally</strong>" → Each mode gets (1/2)RT</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">5. γ Values</p>
# <p style="color: #c9d1d9;">"<strong>3-5-7 Rule</strong>" → Monatomic (3) → 5/3, Diatomic rigid (5) → 7/5, Vibrating (7) → 9/7</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">6. Air Properties</p>
# <p style="color: #c9d1d9;">"<strong>Air is 1.4 times stubborn</strong>" → γ<sub>air</sub> = 1.4</p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #d29922;">⚡ One-Liners for 1-Minute Revision</h3>
#
# <ol style="color: #c9d1d9; line-height: 2.0;">
# <li><strong>Ideal gas</strong> obeys pv = RT or p = ρRT</li>
# <li><strong>R = R̂/M̂</strong>, R̂ = 8.3143 J/(mol·K) universal, M̂ = molar mass</li>
# <li><strong>Valid when</strong>: Low density, high volume, far from saturation</li>
# <li><strong>ρ → 0</strong>: All substances behave ideal</li>
# <li><strong>u = u(T)</strong> only - independent of p, v for ideal gas</li>
# <li><strong>h = h(T)</strong> only - also independent of p, v</li>
# <li><strong>Why?</strong> No intermolecular forces, molecules far apart</li>
# <li><strong>c<sub>v</sub> = du/dT</strong>, c<sub>p</sub> = dh/dT (regular derivatives)</li>
# <li><strong>Golden relation</strong>: c<sub>p</sub> = c<sub>v</sub> + R (memorize this!)</li>
# <li><strong>Pressure microscopic</strong>: p = (1/3)ρ⟨V²⟩ from molecular collisions</li>
# <li><strong>Temperature meaning</strong>: RT = (1/3)⟨V²⟩ (measure of molecular speed²)</li>
# <li><strong>Equipartition</strong>: Each degree of freedom contributes (1/2)RT</li>
# <li><strong>Total u</strong> = (f/2)RT where f = # degrees of freedom</li>
# <li><strong>Monatomic</strong>: f = 3, u = (3/2)RT, c<sub>v</sub> = (3/2)R, γ = 5/3</li>
# <li><strong>Diatomic rigid</strong>: f = 5, u = (5/2)RT, c<sub>v</sub> = (5/2)R, γ = 7/5 = 1.4</li>
# <li><strong>Diatomic vibrating</strong>: f = 7, u = (7/2)RT, c<sub>v</sub> = (7/2)R, γ = 9/7</li>
# <li><strong>Air</strong>: Can be treated as ideal gas with γ ≈ 1.4</li>
# <li><strong>Temperature increases</strong>: Vibrational modes activate, γ decreases</li>
# <li><strong>Constant c assumption</strong>: Valid over limited T ranges for simplicity</li>
# <li><strong>γ = (f+2)/f</strong> general formula for degrees of freedom</li>
# </ol>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #f85149;">🚨 Common Mistakes - Part 3</h3>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px; border-left: 3px solid #f85149;">
# <p style="color: #f85149; font-weight: bold;">❌ Mistake 1:</p>
# <p style="color: #c9d1d9;">Using ideal gas equation for liquids or near saturation</p>
# <p style="color: #3fb950;">✅ Reality: Only valid at low densities, far from vapor dome!</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px; border-left: 3px solid #f85149;">
# <p style="color: #f85149; font-weight: bold;">❌ Mistake 2:</p>
# <p style="color: #c9d1d9;">Thinking u and h depend on pressure for ideal gas</p>
# <p style="color: #3fb950;">✅ Reality: u = u(T) and h = h(T) ONLY!</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px; border-left: 3px solid #f85149;">
# <p style="color: #f85149; font-weight: bold;">❌ Mistake 3:</p>
# <p style="color: #c9d1d9;">Forgetting c<sub>p</sub> = c<sub>v</sub> + R relation</p>
# <p style="color: #3fb950;">✅ Reality: This is THE most tested formula for ideal gas!</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px; border-left: 3px solid #f85149;">
# <p style="color: #f85149; font-weight: bold;">❌ Mistake 4:</p>
# <p style="color: #c9d1d9;">Using wrong γ value (1.667 for air instead of 1.4)</p>
# <p style="color: #3fb950;">✅ Reality: Air is diatomic (γ = 1.4), not monatomic!</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px; border-left: 3px solid #f85149;">
# <p style="color: #f85149; font-weight: bold;">❌ Mistake 5:</p>
# <p style="color: #c9d1d9;">Confusing R (specific) with R̂ (universal)</p>
# <p style="color: #3fb950;">✅ Reality: R = R̂/M̂ (different for each gas), R̂ = same for all!</p>
# </div>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #3fb950;">💎 Pro Tips - Part 3</h3>
#
# <ul style="color: #c9d1d9; line-height: 1.8;">
# <li>🎯 Always check if ideal gas model is valid before using!</li>
# <li>🎯 For air: R ≈ 0.287 kJ/(kg·K), γ = 1.4 - memorize these!</li>
# <li>🎯 c<sub>p</sub> = c<sub>v</sub> + R is your best friend - use it always!</li>
# <li>🎯 Temperature is the ONLY variable affecting u and h for ideal gas</li>
# <li>🎯 Equipartition model: u = (f/2)RT is powerful for estimation</li>
# <li>🎯 Monatomic: γ = 5/3, Diatomic: γ = 7/5 - pattern is (f+2)/f</li>
# <li>🎯 Higher temperature → More degrees of freedom active → Lower γ</li>
# <li>🎯 Air properties at room temp: γ = 1.4 validates rigid diatomic model</li>
# <li>🎯 Microscopic view: Pressure from molecular collisions with walls</li>
# <li>🎯 When in doubt about validity, check property charts!</li>
# </ul>
#
# </div>

# %% [markdown]
# <div style="background-color: #161b22; padding: 15px; border-radius: 10px; border: 1px solid #30363d;">
# <h3 style="color: #58a6ff;">🎓 Important Formulas to Memorize</h3>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">1. Ideal Gas Equation:</p>
# <p style="color: #c9d1d9;">pv = RT  or  p = ρRT  or  pV̄ = NR̂T</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">2. Specific Heats Relation:</p>
# <p style="color: #c9d1d9;">c<sub>p</sub> = c<sub>v</sub> + R</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">3. Equipartition:</p>
# <p style="color: #c9d1d9;">u = (f/2)RT,  h = [(f+2)/2]RT,  c<sub>v</sub> = (f/2)R,  c<sub>p</sub> = [(f+2)/2]R</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">4. Gamma:</p>
# <p style="color: #c9d1d9;">γ = c<sub>p</sub>/c<sub>v</sub> = (f+2)/f</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">5. Monatomic (f=3):</p>
# <p style="color: #c9d1d9;">u = (3/2)RT,  c<sub>v</sub> = (3/2)R,  c<sub>p</sub> = (5/2)R,  γ = 5/3</p>
# </div>
#
# <div style="background-color: #0d1117; padding: 10px; border-radius: 5px; margin-top: 10px;">
# <p style="color: #3fb950; font-weight: bold;">6. Diatomic Rigid (f=5):</p>
# <p style="color: #c9d1d9;">u = (5/2)RT,  c<sub>v</sub> = (5/2)R,  c<sub>p</sub> = (7/2)R,  γ = 7/5 = 1.4</p>
# </div>
#
# </div>

# %% [markdown]
# ---
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; text-align: center;">
# <h2 style="color: #ffffff; margin: 0;">🎉 Part 3 Complete!</h2>
# <p style="color: #ffffff; margin-top: 10px; font-size: 18px;">
# Phenomenal work, bro! You've conquered Ideal Gas! 💪
# </p>
# <p style="color: #ffffff; margin-top: 10px;">
# You now understand:<br>
# ✅ Ideal Gas Equation (pv = RT)<br>
# ✅ Why u and h depend only on T<br>
# ✅ The famous c<sub>p</sub> = c<sub>v</sub> + R relation<br>
# ✅ Microscopic derivation of pressure<br>
# ✅ Equipartition model and degrees of freedom<br>
# ✅ Monatomic vs Diatomic gases<br>
# </p>
# <p style="color: #ffeb3b; margin-top: 15px; font-size: 20px; font-weight: bold;">
# Ready for Part 4 (Practice Session)? Just say "NEXT"! 🚀
# </p>
# <p style="color: #ffffff; margin-top: 10px; font-size: 14px;">
# Part 4 will have numerical problems with clickable hints
# </p>
# </div>
